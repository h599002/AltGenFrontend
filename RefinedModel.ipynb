# %% [markdown]
# <a href="https://colab.research.google.com/github/h599002/AltGenFrontend/blob/main/RefinedModel.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Trying to reset

# %%
import tensorflow as tf
from tensorflow.keras import layers, models, callbacks, optimizers, preprocessing
from tensorflow.keras.utils import to_categorical
import keras as keras

gpu_info = !nvidia-smi
gpu_info = '\n'.join(gpu_info)
if gpu_info.find('failed') >= 0:
  print('Not connected to a GPU')
else:
  print(gpu_info)

from psutil import virtual_memory
ram_gb = virtual_memory().total / 1e9
print('Your runtime has {:.1f} gigabytes of available RAM\n'.format(ram_gb))

if ram_gb < 20:
  print('Not using a high-RAM runtime')
else:
  print('You are using a high-RAM runtime!')

# !mkdir -p ~/.kaggle
# !echo '{"username":"vegardaaalbretsen","key":"18f385007d1223dd35dc94f16e311545"}' > ~/.kaggle/kaggle.json
# !chmod 600 ~/.kaggle/kaggle.json
#!kaggle datasets download -d puneet6060/intel-image-classification
#!unzip intel-image-classification.zip -d /content/dataset

# !kaggle datasets download -d seryouxblaster764/fgvc-aircraft
# !unzip fgvc-aircraft.zip -d /content/dataset
# Out:
# Strømmer utdata som er avkortet til de siste 5000 linjene.
#   inflating: /content/dataset/fgvc-aircraft-2013b/fgvc-aircraft-2013b/data/images/1240217.jpg
#   inflating: /content/dataset/fgvc-aircraft-2013b/fgvc-aircraft-2013b/data/images/1240265.jpg
#   inflating: /content/dataset/fgvc-aircraft-2013b/fgvc-aircraft-2013b/data/images/1240315.jpg
#   inflating: /content/dataset/fgvc-aircraft-2013b/fgvc-aircraft-2013b/data/images/1240316.jpg
#   inflating: /content/dataset/fgvc-aircraft-2013b/fgvc-aircraft-2013b/data/images/1240324.jpg
#   inflating: /content/dataset/fgvc-aircraft-2013b/fgvc-aircraft-2013b/data/images/1240500.jpg
#   inflating: /content/dataset/fgvc-aircraft-2013b/fgvc-aircraft-2013b/data/images/1240501.jpg
#   inflating: /content/dataset/fgvc-aircraft-2013b/fgvc-aircraft-2013b/data/images/1240881.jpg
#   inflating: /content/dataset/fgvc-aircraft-2013b/fgvc-aircraft-2013b/data/images/1240934.jpg
#   inflating: /content/dataset/fgvc-aircraft-2013b/fgvc-aircraft-2013b/data/images/1240939.jpg
#   inflating: /content/dataset/fgvc-aircraft-2013b/fgvc-aircraft-2013b/data/images/1241521.jpg
#   inflating: /content/dataset/fgvc-aircraft-2013b/fgvc-aircraft-2013b/data/images/1241522.jpg
#   inflating: /content/dataset/fgvc-aircraft-2013b/fgvc-aircraft-2013b/data/images/1241545.jpg
#   inflating: /content/dataset/fgvc-aircraft-2013b/fgvc-aircraft-2013b/data/images/1242242.jpg
#   inflating: /content/dataset/fgvc-aircraft-2013b/fgvc-aircraft-2013b/data/images/1242253.jpg
#   inflating: /content/dataset/fgvc-aircraft-2013b/fgvc-aircraft-2013b/data/images/1242658.jpg
#   inflating: /content/dataset/fgvc-aircraft-2013b/fgvc-aircraft-2013b/data/images/1243068.jpg
#   inflating: /content/dataset/fgvc-aircraft-2013b/fgvc-aircraft-2013b/data/images/1243371.jpg
#   inflating: /content/dataset/fgvc-aircraft-2013b/fgvc-aircraft-2013b/data/images/1243372.jpg
#   inflating: /content/dataset/fgvc-aircraft-2013b/fgvc-aircraft-2013b/data/images/1243688.jpg
#   inflating: /content/dataset/fgvc-aircraft-2013b/fgvc-aircraft-2013b/data/images/1244006.jpg
#   inflating: /content/dataset/fgvc-aircraft-2013b/fgvc-aircraft-2013b/data/images/1244285.jpg
#   inflating: /content/dataset/fgvc-aircraft-2013b/fgvc-aircraft-2013b/data/images/1244287.jpg
#   inflating: /content/dataset/fgvc-aircraft-2013b/fgvc-aircraft-2013b/data/images/1244288.jpg
#   inflating: /content/dataset/fgvc-aircraft-2013b/fgvc-aircraft-2013b/data/images/1244289.jpg
#   inflating: /content/dataset/fgvc-aircraft-2013b/fgvc-aircraft-2013b/data/images/1244306.jpg
#   inflating: /content/dataset/fgvc-aircraft-2013b/fgvc-aircraft-2013b/data/images/1244348.jpg
#   inflating: /content/dataset/fgvc-aircraft-2013b/fgvc-aircraft-2013b/data/images/1244362.jpg
#   inflating: /content/dataset/fgvc-aircraft-2013b/fgvc-aircraft-2013b/data/images/1244468.jpg
#   inflating: /content/dataset/fgvc-aircraft-2013b/fgvc-aircraft-2013b/data/images/1244620.jpg
#   inflating: /content/dataset/fgvc-aircraft-2013b/fgvc-aircraft-2013b/data/images/1244625.jpg
#   inflating: /content/dataset/fgvc-aircraft-2013b/fgvc-aircraft-2013b/data/images/1244687.jpg
#   inflating: /content/dataset/fgvc-aircraft-2013b/fgvc-aircraft-2013b/data/images/1244756.jpg
#   inflating: /content/dataset/fgvc-aircraft-2013b/fgvc-aircraft-2013b/data/images/1244757.jpg
#   inflating: /content/dataset/fgvc-aircraft-2013b/fgvc-aircraft-2013b/data/images/1244760.jpg
#   inflating: /content/dataset/fgvc-aircraft-2013b/fgvc-aircraft-2013b/data/images/1244762.jpg
#   inflating: /content/dataset/fgvc-aircraft-2013b/fgvc-aircraft-2013b/data/images/1244763.jpg
#   inflating: /content/dataset/fgvc-aircraft-2013b/fgvc-aircraft-2013b/data/images/1244766.jpg
#   inflating: /content/dataset/fgvc-aircraft-2013b/fgvc-aircraft-2013b/data/images/1245051.jpg
#   inflating: /content/dataset/fgvc-aircraft-2013b/fgvc-aircraft-2013b/data/images/1245209.jpg
#   inflating: /content/dataset/fgvc-aircraft-2013b/fgvc-aircraft-2013b/data/images/1245215.jpg
#   inflating: /content/dataset/fgvc-aircraft-2013b/fgvc-aircraft-2013b/data/images/1245276.jpg
#   inflating: /content/dataset/fgvc-aircraft-2013b/fgvc-aircraft-2013b/data/images/1245559.jpg
#   inflating: /content/dataset/fgvc-aircraft-2013b/fgvc-aircraft-2013b/data/images/1245562.jpg
#   inflating: /content/dataset/fgvc-aircraft-2013b/fgvc-aircraft-2013b/data/images/1245887.jpg
#   inflating: /content/dataset/fgvc-aircraft-2013b/fgvc-aircraft-2013b/data/images/1246013.jpg
#   inflating: /content/dataset/fgvc-aircraft-2013b/fgvc-aircraft-2013b/data/images/1246392.jpg
#   inflating: /content/dataset/fgvc-aircraft-2013b/fgvc-aircraft-2013b/data/images/1246713.jpg
#   inflating: /content/dataset/fgvc-aircraft-2013b/fgvc-aircraft-2013b/data/images/1246917.jpg
#   inflating: /content/dataset/fgvc-aircraft-2013b/fgvc-aircraft-2013b/data/images/1246918.jpg
#   inflating: /content/dataset/fgvc-aircraft-2013b/fgvc-aircraft-2013b/data/images/1246986.jpg
#   inflating: /content/dataset/fgvc-aircraft-2013b/fgvc-aircraft-2013b/data/images/1246993.jpg
#   inflating: /content/dataset/fgvc-aircraft-2013b/fgvc-aircraft-2013b/data/images/1248046.jpg
#   inflating: /content/dataset/fgvc-aircraft-2013b/fgvc-aircraft-2013b/data/images/1248148.jpg
#   inflating: /content/dataset/fgvc-aircraft-2013b/fgvc-aircraft-2013b/data/images/1249553.jpg
#   inflating: /content/dataset/fgvc-aircraft-2013b/fgvc-aircraft-2013b/data/images/1249564.jpg
#   inflating: /content/dataset/fgvc-aircraft-2013b/fgvc-aircraft-2013b/data/images/1249912.jpg
#   inflating: /content/dataset/fgvc-aircraft-2013b/fgvc-aircraft-2013b/data/images/1250050.jpg
#   inflating: /content/dataset/fgvc-aircraft-2013b/fgvc-aircraft-2013b/data/images/1250052.jpg
#   inflating: /content/dataset/fgvc-aircraft-2013b/fgvc-aircraft-2013b/data/images/1250249.jpg
#   inflating: /content/dataset/fgvc-aircraft-2013b/fgvc-aircraft-2013b/data/images/1250251.jpg
#   inflating: /content/dataset/fgvc-aircraft-2013b/fgvc-aircraft-2013b/data/images/1250523.jpg
#   inflating: /content/dataset/fgvc-aircraft-2013b/fgvc-aircraft-2013b/data/images/1250763.jpg
#   inflating: /content/dataset/fgvc-aircraft-2013b/fgvc-aircraft-2013b/data/images/1250932.jpg
#   inflating: /content/dataset/fgvc-aircraft-2013b/fgvc-aircraft-2013b/data/images/1251094.jpg
#   inflating: /content/dataset/fgvc-aircraft-2013b/fgvc-aircraft-2013b/data/images/1251098.jpg
#   inflating: /content/dataset/fgvc-aircraft-2013b/fgvc-aircraft-2013b/data/images/1251237.jpg
#   inflating: /content/dataset/fgvc-aircraft-2013b/fgvc-aircraft-2013b/data/images/1251240.jpg
#   inflating: /content/dataset/fgvc-aircraft-2013b/fgvc-aircraft-2013b/data/images/1251242.jpg
#   inflating: /content/dataset/fgvc-aircraft-2013b/fgvc-aircraft-2013b/data/images/1251253.jpg
#   inflating: /content/dataset/fgvc-aircraft-2013b/fgvc-aircraft-2013b/data/images/1251289.jpg
#   inflating: /content/dataset/fgvc-aircraft-2013b/fgvc-aircraft-2013b/data/images/1251379.jpg
#   inflating: /content/dataset/fgvc-aircraft-2013b/fgvc-aircraft-2013b/data/images/1251380.jpg
#   inflating: /content/dataset/fgvc-aircraft-2013b/fgvc-aircraft-2013b/data/images/1251381.jpg
#   inflating: /content/dataset/fgvc-aircraft-2013b/fgvc-aircraft-2013b/data/images/1251382.jpg
#   inflating: /content/dataset/fgvc-aircraft-2013b/fgvc-aircraft-2013b/data/images/1251385.jpg
#   inflating: /content/dataset/fgvc-aircraft-2013b/fgvc-aircraft-2013b/data/images/1251519.jpg
#   inflating: /content/dataset/fgvc-aircraft-2013b/fgvc-aircraft-2013b/data/images/1251686.jpg
#   inflating: /content/dataset/fgvc-aircraft-2013b/fgvc-aircraft-2013b/data/images/1251764.jpg
#   inflating: /content/dataset/fgvc-aircraft-2013b/fgvc-aircraft-2013b/data/images/1251766.jpg
#   inflating: /content/dataset/fgvc-aircraft-2013b/fgvc-aircraft-2013b/data/images/1251898.jpg
#   inflating: /content/dataset/fgvc-aircraft-2013b/fgvc-aircraft-2013b/data/images/1252026.jpg
#   inflating: /content/dataset/fgvc-aircraft-2013b/fgvc-aircraft-2013b/data/images/1252037.jpg
#   inflating: /content/dataset/fgvc-aircraft-2013b/fgvc-aircraft-2013b/data/images/1252081.jpg
#   inflating: /content/dataset/fgvc-aircraft-2013b/fgvc-aircraft-2013b/data/images/1252082.jpg
#   inflating: /content/dataset/fgvc-aircraft-2013b/fgvc-aircraft-2013b/data/images/1252131.jpg
#   inflating: /content/dataset/fgvc-aircraft-2013b/fgvc-aircraft-2013b/data/images/1252133.jpg
#   inflating: /content/dataset/fgvc-aircraft-2013b/fgvc-aircraft-2013b/data/images/1252312.jpg
#   inflating: /content/dataset/fgvc-aircraft-2013b/fgvc-aircraft-2013b/data/images/1252819.jpg
#   inflating: /content/dataset/fgvc-aircraft-2013b/fgvc-aircraft-2013b/data/images/1252832.jpg
#   inflating: /content/dataset/fgvc-aircraft-2013b/fgvc-aircraft-2013b/data/images/1253163.jpg
#   inflating: /content/dataset/fgvc-aircraft-2013b/fgvc-aircraft-2013b/data/images/1253247.jpg
#   inflating: /content/dataset/fgvc-aircraft-2013b/fgvc-aircraft-2013b/data/images/1253432.jpg
#   inflating: /content/dataset/fgvc-aircraft-2013b/fgvc-aircraft-2013b/data/images/1253442.jpg
#   inflating: /content/dataset/fgvc-aircraft-2013b/fgvc-aircraft-2013b/data/images/1253449.jpg
#   inflating: /content/dataset/fgvc-aircraft-2013b/fgvc-aircraft-2013b/data/images/1253455.jpg
#   inflating: /content/dataset/fgvc-aircraft-2013b/fgvc-aircraft-2013b/data/images/1253530.jpg
#   inflating: /content/dataset/fgvc-aircraft-2013b/fgvc-aircraft-2013b/data/images/1253533.jpg
#   inflating: /content/dataset/fgvc-aircraft-2013b/fgvc-aircraft-2013b/data/images/1253784.jpg
#   inflating: /content/dataset/fgvc-aircraft-2013b/fgvc-aircraft-2013b/data/images/1253857.jpg
#   inflating: /content/dataset/fgvc-aircraft-2013b/fgvc-aircraft-2013b/data/images/1254089.jpg
#   inflating: /content/dataset/fgvc-aircraft-2013b/fgvc-aircraft-2013b/data/images/1254187.jpg
#   inflating: /content/dataset/fgvc-aircraft-2013b/fgvc-aircraft-2013b/data/images/1254451.jpg
#   inflating: /content/dataset/fgvc-aircraft-2013b/fgvc-aircraft-2013b/data/images/1254468.jpg
#   inflating: /content/dataset/fgvc-aircraft-2013b/fgvc-aircraft-2013b/data/images/1254668.jpg
#   inflating: /content/dataset/fgvc-aircraft-2013b/fgvc-aircraft-2013b/data/images/1254669.jpg
#   inflating: /content/dataset/fgvc-aircraft-2013b/fgvc-aircraft-2013b/data/images/1254806.jpg
#   inflating: /content/dataset/fgvc-aircraft-2013b/fgvc-aircraft-2013b/data/images/1254962.jpg
#   inflating: /content/dataset/fgvc-aircraft-2013b/fgvc-aircraft-2013b/data/images/1255006.jpg
#   inflating: /content/dataset/fgvc-aircraft-2013b/fgvc-aircraft-2013b/data/images/1255008.jpg
#   inflating: /content/dataset/fgvc-aircraft-2013b/fgvc-aircraft-2013b/data/images/1255033.jpg
#   inflating: /content/dataset/fgvc-aircraft-2013b/fgvc-aircraft-2013b/data/images/1255434.jpg
#   inflating: /content/dataset/fgvc-aircraft-2013b/fgvc-aircraft-2013b/data/images/1255446.jpg
#   inflating: /content/dataset/fgvc-aircraft-2013b/fgvc-aircraft-2013b/data/images/1255496.jpg
#   inflating: /content/dataset/fgvc-aircraft-2013b/fgvc-aircraft-2013b/data/images/1255533.jpg
#   inflating: /content/dataset/fgvc-aircraft-2013b/fgvc-aircraft-2013b/data/images/1255661.jpg
#   inflating: /content/dataset/fgvc-aircraft-2013b/fgvc-aircraft-2013b/data/images/1255662.jpg
#   inflating: /content/dataset/fgvc-aircraft-2013b/fgvc-aircraft-2013b/data/images/1255726.jpg
#   inflating: /content/dataset/fgvc-aircraft-2013b/fgvc-aircraft-2013b/data/images/1255792.jpg
#   inflating: /content/dataset/fgvc-aircraft-2013b/fgvc-aircraft-2013b/data/images/1255844.jpg
#   inflating: /content/dataset/fgvc-aircraft-2013b/fgvc-aircraft-2013b/data/images/1255846.jpg
#   inflating: /content/dataset/fgvc-aircraft-2013b/fgvc-aircraft-2013b/data/images/1256035.jpg
#   inflating: /content/dataset/fgvc-aircraft-2013b/fgvc-aircraft-2013b/data/images/1256114.jpg
#   inflating: /content/dataset/fgvc-aircraft-2013b/fgvc-aircraft-2013b/data/images/1256349.jpg
#   inflating: /content/dataset/fgvc-aircraft-2013b/fgvc-aircraft-2013b/data/images/1256464.jpg
#   inflating: /content/dataset/fgvc-aircraft-2013b/fgvc-aircraft-2013b/data/images/1256465.jpg
#   inflating: /content/dataset/fgvc-aircraft-2013b/fgvc-aircraft-2013b/data/images/1256472.jpg
#   inflating: /content/dataset/fgvc-aircraft-2013b/fgvc-aircraft-2013b/data/images/1256475.jpg
#   inflating: /content/dataset/fgvc-aircraft-2013b/fgvc-aircraft-2013b/data/images/1256682.jpg
#   inflating: /content/dataset/fgvc-aircraft-2013b/fgvc-aircraft-2013b/data/images/1256683.jpg
#   inflating: /content/dataset/fgvc-aircraft-2013b/fgvc-aircraft-2013b/data/images/1256726.jpg
#   inflating: /content/dataset/fgvc-aircraft-2013b/fgvc-aircraft-2013b/data/images/1257110.jpg
#   inflating: /content/dataset/fgvc-aircraft-2013b/fgvc-aircraft-2013b/data/images/1257119.jpg
#   inflating: /content/dataset/fgvc-aircraft-2013b/fgvc-aircraft-2013b/data/images/1258138.jpg
#   inflating: /content/dataset/fgvc-aircraft-2013b/fgvc-aircraft-2013b/data/images/1258139.jpg
#   inflating: /content/dataset/fgvc-aircraft-2013b/fgvc-aircraft-2013b/data/images/1258401.jpg
#   inflating: /content/dataset/fgvc-aircraft-2013b/fgvc-aircraft-2013b/data/images/1258418.jpg
#   inflating: /content/dataset/fgvc-aircraft-2013b/fgvc-aircraft-2013b/data/images/1258502.jpg
#   inflating: /content/dataset/fgvc-aircraft-2013b/fgvc-aircraft-2013b/data/images/1258526.jpg
#   inflating: /content/dataset/fgvc-aircraft-2013b/fgvc-aircraft-2013b/data/images/1258555.jpg
#   inflating: /content/dataset/fgvc-aircraft-2013b/fgvc-aircraft-2013b/data/images/1258557.jpg
#   inflating: /content/dataset/fgvc-aircraft-2013b/fgvc-aircraft-2013b/data/images/1258559.jpg
#   inflating: /content/dataset/fgvc-aircraft-2013b/fgvc-aircraft-2013b/data/images/1258561.jpg
#   inflating: /content/dataset/fgvc-aircraft-2013b/fgvc-aircraft-2013b/data/images/1258577.jpg
#   inflating: /content/dataset/fgvc-aircraft-2013b/fgvc-aircraft-2013b/data/images/1258646.jpg
#   inflating: /content/dataset/fgvc-aircraft-2013b/fgvc-aircraft-2013b/data/images/1258662.jpg
#   inflating: /content/dataset/fgvc-aircraft-2013b/fgvc-aircraft-2013b/data/images/1258663.jpg
#   inflating: /content/dataset/fgvc-aircraft-2013b/fgvc-aircraft-2013b/data/images/1258703.jpg
#   inflating: /content/dataset/fgvc-aircraft-2013b/fgvc-aircraft-2013b/data/images/1258704.jpg
#   inflating: /content/dataset/fgvc-aircraft-2013b/fgvc-aircraft-2013b/data/images/1259067.jpg
#   inflating: /content/dataset/fgvc-aircraft-2013b/fgvc-aircraft-2013b/data/images/1259151.jpg
#   inflating: /content/dataset/fgvc-aircraft-2013b/fgvc-aircraft-2013b/data/images/1259152.jpg
#   inflating: /content/dataset/fgvc-aircraft-2013b/fgvc-aircraft-2013b/data/images/1259554.jpg
#   inflating: /content/dataset/fgvc-aircraft-2013b/fgvc-aircraft-2013b/data/images/1259556.jpg
#   inflating: /content/dataset/fgvc-aircraft-2013b/fgvc-aircraft-2013b/data/images/1259623.jpg
#   inflating: /content/dataset/fgvc-aircraft-2013b/fgvc-aircraft-2013b/data/images/1259625.jpg
#   inflating: /content/dataset/fgvc-aircraft-2013b/fgvc-aircraft-2013b/data/images/1259710.jpg
#   inflating: /content/dataset/fgvc-aircraft-2013b/fgvc-aircraft-2013b/data/images/1260282.jpg
#   inflating: /content/dataset/fgvc-aircraft-2013b/fgvc-aircraft-2013b/data/images/1260329.jpg
#   inflating: /content/dataset/fgvc-aircraft-2013b/fgvc-aircraft-2013b/data/images/1260332.jpg
#   inflating: /content/dataset/fgvc-aircraft-2013b/fgvc-aircraft-2013b/data/images/1260391.jpg
#   inflating: /content/dataset/fgvc-aircraft-2013b/fgvc-aircraft-2013b/data/images/1260718.jpg
#   inflating: /content/dataset/fgvc-aircraft-2013b/fgvc-aircraft-2013b/data/images/1260868.jpg
#   inflating: /content/dataset/fgvc-aircraft-2013b/fgvc-aircraft-2013b/data/images/1260869.jpg
#   inflating: /content/dataset/fgvc-aircraft-2013b/fgvc-aircraft-2013b/data/images/1260870.jpg
#   inflating: /content/dataset/fgvc-aircraft-2013b/fgvc-aircraft-2013b/data/images/1260949.jpg
#   inflating: /content/dataset/fgvc-aircraft-2013b/fgvc-aircraft-2013b/data/images/1261329.jpg
#   inflating: /content/dataset/fgvc-aircraft-2013b/fgvc-aircraft-2013b/data/images/1261342.jpg
#   inflating: /content/dataset/fgvc-aircraft-2013b/fgvc-aircraft-2013b/data/images/1261350.jpg
#   inflating: /content/dataset/fgvc-aircraft-2013b/fgvc-aircraft-2013b/data/images/1261424.jpg
#   inflating: /content/dataset/fgvc-aircraft-2013b/fgvc-aircraft-2013b/data/images/1261425.jpg
#   inflating: /content/dataset/fgvc-aircraft-2013b/fgvc-aircraft-2013b/data/images/1261752.jpg
#   inflating: /content/dataset/fgvc-aircraft-2013b/fgvc-aircraft-2013b/data/images/1261955.jpg
#   inflating: /content/dataset/fgvc-aircraft-2013b/fgvc-aircraft-2013b/data/images/1261956.jpg
#   inflating: /content/dataset/fgvc-aircraft-2013b/fgvc-aircraft-2013b/data/images/1261973.jpg
#   inflating: /content/dataset/fgvc-aircraft-2013b/fgvc-aircraft-2013b/data/images/1263090.jpg
#   inflating: /content/dataset/fgvc-aircraft-2013b/fgvc-aircraft-2013b/data/images/1264190.jpg
#   inflating: /content/dataset/fgvc-aircraft-2013b/fgvc-aircraft-2013b/data/images/1264191.jpg
#   inflating: /content/dataset/fgvc-aircraft-2013b/fgvc-aircraft-2013b/data/images/1264479.jpg
#   inflating: /content/dataset/fgvc-aircraft-2013b/fgvc-aircraft-2013b/data/images/1265320.jpg
#   inflating: /content/dataset/fgvc-aircraft-2013b/fgvc-aircraft-2013b/data/images/1265380.jpg
#   inflating: /content/dataset/fgvc-aircraft-2013b/fgvc-aircraft-2013b/data/images/1265381.jpg
#   inflating: /content/dataset/fgvc-aircraft-2013b/fgvc-aircraft-2013b/data/images/1265382.jpg
#   inflating: /content/dataset/fgvc-aircraft-2013b/fgvc-aircraft-2013b/data/images/1265817.jpg
#   inflating: /content/dataset/fgvc-aircraft-2013b/fgvc-aircraft-2013b/data/images/1266018.jpg
#   inflating: /content/dataset/fgvc-aircraft-2013b/fgvc-aircraft-2013b/data/images/1266143.jpg
#   inflating: /content/dataset/fgvc-aircraft-2013b/fgvc-aircraft-2013b/data/images/1266149.jpg
#   inflating: /content/dataset/fgvc-aircraft-2013b/fgvc-aircraft-2013b/data/images/1266357.jpg
#   inflating: /content/dataset/fgvc-aircraft-2013b/fgvc-aircraft-2013b/data/images/1266977.jpg
#   inflating: /content/dataset/fgvc-aircraft-2013b/fgvc-aircraft-2013b/data/images/1267012.jpg
#   inflating: /content/dataset/fgvc-aircraft-2013b/fgvc-aircraft-2013b/data/images/1267074.jpg
#   inflating: /content/dataset/fgvc-aircraft-2013b/fgvc-aircraft-2013b/data/images/1267078.jpg
#   inflating: /content/dataset/fgvc-aircraft-2013b/fgvc-aircraft-2013b/data/images/1267455.jpg
#   inflating: /content/dataset/fgvc-aircraft-2013b/fgvc-aircraft-2013b/data/images/1267520.jpg
#   inflating: /content/dataset/fgvc-aircraft-2013b/fgvc-aircraft-2013b/data/images/1268068.jpg
#   inflating: /content/dataset/fgvc-aircraft-2013b/fgvc-aircraft-2013b/data/images/1268480.jpg
#   inflating: /content/dataset/fgvc-aircraft-2013b/fgvc-aircraft-2013b/data/images/1268547.jpg
#   inflating: /content/dataset/fgvc-aircraft-2013b/fgvc-aircraft-2013b/data/images/1269006.jpg
#   inflating: /content/dataset/fgvc-aircraft-2013b/fgvc-aircraft-2013b/data/images/1269007.jpg
#   inflating: /content/dataset/fgvc-aircraft-2013b/fgvc-aircraft-2013b/data/images/1269238.jpg
#   inflating: /content/dataset/fgvc-aircraft-2013b/fgvc-aircraft-2013b/data/images/1270583.jpg
#   inflating: /content/dataset/fgvc-aircraft-2013b/fgvc-aircraft-2013b/data/images/1270601.jpg
#   inflating: /content/dataset/fgvc-aircraft-2013b/fgvc-aircraft-2013b/data/images/1270604.jpg
#   inflating: /content/dataset/fgvc-aircraft-2013b/fgvc-aircraft-2013b/data/images/1270710.jpg
#   inflating: /content/dataset/fgvc-aircraft-2013b/fgvc-aircraft-2013b/data/images/1270714.jpg
#   inflating: /content/dataset/fgvc-aircraft-2013b/fgvc-aircraft-2013b/data/images/1271461.jpg
#   inflating: /content/dataset/fgvc-aircraft-2013b/fgvc-aircraft-2013b/data/images/1271552.jpg
#   inflating: /content/dataset/fgvc-aircraft-2013b/fgvc-aircraft-2013b/data/images/1271556.jpg
#   inflating: /content/dataset/fgvc-aircraft-2013b/fgvc-aircraft-2013b/data/images/1272007.jpg
#   inflating: /content/dataset/fgvc-aircraft-2013b/fgvc-aircraft-2013b/data/images/1272291.jpg
#   inflating: /content/dataset/fgvc-aircraft-2013b/fgvc-aircraft-2013b/data/images/1272643.jpg
#   inflating: /content/dataset/fgvc-aircraft-2013b/fgvc-aircraft-2013b/data/images/1272644.jpg
#   inflating: /content/dataset/fgvc-aircraft-2013b/fgvc-aircraft-2013b/data/images/1272696.jpg
#   inflating: /content/dataset/fgvc-aircraft-2013b/fgvc-aircraft-2013b/data/images/1272698.jpg
#   inflating: /content/dataset/fgvc-aircraft-2013b/fgvc-aircraft-2013b/data/images/1272699.jpg
#   inflating: /content/dataset/fgvc-aircraft-2013b/fgvc-aircraft-2013b/data/images/1272849.jpg
#   inflating: /content/dataset/fgvc-aircraft-2013b/fgvc-aircraft-2013b/data/images/1273293.jpg
#   inflating: /content/dataset/fgvc-aircraft-2013b/fgvc-aircraft-2013b/data/images/1273373.jpg
#   inflating: /content/dataset/fgvc-aircraft-2013b/fgvc-aircraft-2013b/data/images/1273374.jpg
#   inflating: /content/dataset/fgvc-aircraft-2013b/fgvc-aircraft-2013b/data/images/1274483.jpg
#   inflating: /content/dataset/fgvc-aircraft-2013b/fgvc-aircraft-2013b/data/images/1274803.jpg
#   inflating: /content/dataset/fgvc-aircraft-2013b/fgvc-aircraft-2013b/data/images/1275786.jpg
#   inflating: /content/dataset/fgvc-aircraft-2013b/fgvc-aircraft-2013b/data/images/1275811.jpg
#   inflating: /content/dataset/fgvc-aircraft-2013b/fgvc-aircraft-2013b/data/images/1276405.jpg
#   inflating: /content/dataset/fgvc-aircraft-2013b/fgvc-aircraft-2013b/data/images/1276526.jpg
#   inflating: /content/dataset/fgvc-aircraft-2013b/fgvc-aircraft-2013b/data/images/1276530.jpg
#   inflating: /content/dataset/fgvc-aircraft-2013b/fgvc-aircraft-2013b/data/images/1276588.jpg
#   inflating: /content/dataset/fgvc-aircraft-2013b/fgvc-aircraft-2013b/data/images/1276718.jpg
#   inflating: /content/dataset/fgvc-aircraft-2013b/fgvc-aircraft-2013b/data/images/1276727.jpg
#   inflating: /content/dataset/fgvc-aircraft-2013b/fgvc-aircraft-2013b/data/images/1277137.jpg
#   inflating: /content/dataset/fgvc-aircraft-2013b/fgvc-aircraft-2013b/data/images/1277604.jpg
#   inflating: /content/dataset/fgvc-aircraft-2013b/fgvc-aircraft-2013b/data/images/1277617.jpg
#   inflating: /content/dataset/fgvc-aircraft-2013b/fgvc-aircraft-2013b/data/images/1277619.jpg
#   inflating: /content/dataset/fgvc-aircraft-2013b/fgvc-aircraft-2013b/data/images/1277631.jpg
#   inflating: /content/dataset/fgvc-aircraft-2013b/fgvc-aircraft-2013b/data/images/1277633.jpg
#   inflating: /content/dataset/fgvc-aircraft-2013b/fgvc-aircraft-2013b/data/images/1277981.jpg
#   inflating: /content/dataset/fgvc-aircraft-2013b/fgvc-aircraft-2013b/data/images/1277982.jpg
#   inflating: /content/dataset/fgvc-aircraft-2013b/fgvc-aircraft-2013b/data/images/1277986.jpg
#   inflating: /content/dataset/fgvc-aircraft-2013b/fgvc-aircraft-2013b/data/images/1277987.jpg
#   inflating: /content/dataset/fgvc-aircraft-2013b/fgvc-aircraft-2013b/data/images/1277988.jpg
#   inflating: /content/dataset/fgvc-aircraft-2013b/fgvc-aircraft-2013b/data/images/1278085.jpg
#   inflating: /content/dataset/fgvc-aircraft-2013b/fgvc-aircraft-2013b/data/images/1278141.jpg
#   inflating: /content/dataset/fgvc-aircraft-2013b/fgvc-aircraft-2013b/data/images/1278429.jpg
#   inflating: /content/dataset/fgvc-aircraft-2013b/fgvc-aircraft-2013b/data/images/1278473.jpg
#   inflating: /content/dataset/fgvc-aircraft-2013b/fgvc-aircraft-2013b/data/images/1279666.jpg
#   inflating: /content/dataset/fgvc-aircraft-2013b/fgvc-aircraft-2013b/data/images/1279709.jpg
#   inflating: /content/dataset/fgvc-aircraft-2013b/fgvc-aircraft-2013b/data/images/1279747.jpg
#   inflating: /content/dataset/fgvc-aircraft-2013b/fgvc-aircraft-2013b/data/images/1279903.jpg
#   inflating: /content/dataset/fgvc-aircraft-2013b/fgvc-aircraft-2013b/data/images/1280039.jpg
#   inflating: /content/dataset/fgvc-aircraft-2013b/fgvc-aircraft-2013b/data/images/1280040.jpg
#   inflating: /content/dataset/fgvc-aircraft-2013b/fgvc-aircraft-2013b/data/images/1280138.jpg
#   inflating: /content/dataset/fgvc-aircraft-2013b/fgvc-aircraft-2013b/data/images/1280176.jpg
#   inflating: /content/dataset/fgvc-aircraft-2013b/fgvc-aircraft-2013b/data/images/1280503.jpg
#   inflating: /content/dataset/fgvc-aircraft-2013b/fgvc-aircraft-2013b/data/images/1280724.jpg
#   inflating: /content/dataset/fgvc-aircraft-2013b/fgvc-aircraft-2013b/data/images/1280976.jpg
#   inflating: /content/dataset/fgvc-aircraft-2013b/fgvc-aircraft-2013b/data/images/1281453.jpg
#   inflating: /content/dataset/fgvc-aircraft-2013b/fgvc-aircraft-2013b/data/images/1281454.jpg
#   inflating: /content/dataset/fgvc-aircraft-2013b/fgvc-aircraft-2013b/data/images/1281574.jpg
#   inflating: /content/dataset/fgvc-aircraft-2013b/fgvc-aircraft-2013b/data/images/1281620.jpg
#   inflating: /content/dataset/fgvc-aircraft-2013b/fgvc-aircraft-2013b/data/images/1281757.jpg
#   inflating: /content/dataset/fgvc-aircraft-2013b/fgvc-aircraft-2013b/data/images/1281857.jpg
#   inflating: /content/dataset/fgvc-aircraft-2013b/fgvc-aircraft-2013b/data/images/1281985.jpg
#   inflating: /content/dataset/fgvc-aircraft-2013b/fgvc-aircraft-2013b/data/images/1282206.jpg
#   inflating: /content/dataset/fgvc-aircraft-2013b/fgvc-aircraft-2013b/data/images/1282348.jpg
#   inflating: /content/dataset/fgvc-aircraft-2013b/fgvc-aircraft-2013b/data/images/1283206.jpg
#   inflating: /content/dataset/fgvc-aircraft-2013b/fgvc-aircraft-2013b/data/images/1283207.jpg
#   inflating: /content/dataset/fgvc-aircraft-2013b/fgvc-aircraft-2013b/data/images/1283304.jpg
#   inflating: /content/dataset/fgvc-aircraft-2013b/fgvc-aircraft-2013b/data/images/1283328.jpg
#   inflating: /content/dataset/fgvc-aircraft-2013b/fgvc-aircraft-2013b/data/images/1283508.jpg
#   inflating: /content/dataset/fgvc-aircraft-2013b/fgvc-aircraft-2013b/data/images/1283510.jpg
#   inflating: /content/dataset/fgvc-aircraft-2013b/fgvc-aircraft-2013b/data/images/1283512.jpg
#   inflating: /content/dataset/fgvc-aircraft-2013b/fgvc-aircraft-2013b/data/images/1283644.jpg
#   inflating: /content/dataset/fgvc-aircraft-2013b/fgvc-aircraft-2013b/data/images/1283645.jpg
#   inflating: /content/dataset/fgvc-aircraft-2013b/fgvc-aircraft-2013b/data/images/1283646.jpg
#   inflating: /content/dataset/fgvc-aircraft-2013b/fgvc-aircraft-2013b/data/images/1283779.jpg
#   inflating: /content/dataset/fgvc-aircraft-2013b/fgvc-aircraft-2013b/data/images/1283832.jpg
#   inflating: /content/dataset/fgvc-aircraft-2013b/fgvc-aircraft-2013b/data/images/1283842.jpg
#   inflating: /content/dataset/fgvc-aircraft-2013b/fgvc-aircraft-2013b/data/images/1283846.jpg
#   inflating: /content/dataset/fgvc-aircraft-2013b/fgvc-aircraft-2013b/data/images/1283960.jpg
#   inflating: /content/dataset/fgvc-aircraft-2013b/fgvc-aircraft-2013b/data/images/1284221.jpg
#   inflating: /content/dataset/fgvc-aircraft-2013b/fgvc-aircraft-2013b/data/images/1284223.jpg
#   inflating: /content/dataset/fgvc-aircraft-2013b/fgvc-aircraft-2013b/data/images/1284226.jpg
#   inflating: /content/dataset/fgvc-aircraft-2013b/fgvc-aircraft-2013b/data/images/1284239.jpg
#   inflating: /content/dataset/fgvc-aircraft-2013b/fgvc-aircraft-2013b/data/images/1284367.jpg
#   inflating: /content/dataset/fgvc-aircraft-2013b/fgvc-aircraft-2013b/data/images/1284591.jpg
#   inflating: /content/dataset/fgvc-aircraft-2013b/fgvc-aircraft-2013b/data/images/1285638.jpg
#   inflating: /content/dataset/fgvc-aircraft-2013b/fgvc-aircraft-2013b/data/images/1285916.jpg
#   inflating: /content/dataset/fgvc-aircraft-2013b/fgvc-aircraft-2013b/data/images/1285957.jpg
#   inflating: /content/dataset/fgvc-aircraft-2013b/fgvc-aircraft-2013b/data/images/1286165.jpg
#   inflating: /content/dataset/fgvc-aircraft-2013b/fgvc-aircraft-2013b/data/images/1286492.jpg
#   inflating: /content/dataset/fgvc-aircraft-2013b/fgvc-aircraft-2013b/data/images/1287207.jpg
#   inflating: /content/dataset/fgvc-aircraft-2013b/fgvc-aircraft-2013b/data/images/1287238.jpg
#   inflating: /content/dataset/fgvc-aircraft-2013b/fgvc-aircraft-2013b/data/images/1287590.jpg
#   inflating: /content/dataset/fgvc-aircraft-2013b/fgvc-aircraft-2013b/data/images/1287591.jpg
#   inflating: /content/dataset/fgvc-aircraft-2013b/fgvc-aircraft-2013b/data/images/1287636.jpg
#   inflating: /content/dataset/fgvc-aircraft-2013b/fgvc-aircraft-2013b/data/images/1287644.jpg
#   inflating: /content/dataset/fgvc-aircraft-2013b/fgvc-aircraft-2013b/data/images/1287650.jpg
#   inflating: /content/dataset/fgvc-aircraft-2013b/fgvc-aircraft-2013b/data/images/1287739.jpg
#   inflating: /content/dataset/fgvc-aircraft-2013b/fgvc-aircraft-2013b/data/images/1287740.jpg
#   inflating: /content/dataset/fgvc-aircraft-2013b/fgvc-aircraft-2013b/data/images/1288222.jpg
#   inflating: /content/dataset/fgvc-aircraft-2013b/fgvc-aircraft-2013b/data/images/1288661.jpg
#   inflating: /content/dataset/fgvc-aircraft-2013b/fgvc-aircraft-2013b/data/images/1288663.jpg
#   inflating: /content/dataset/fgvc-aircraft-2013b/fgvc-aircraft-2013b/data/images/1288665.jpg
#   inflating: /content/dataset/fgvc-aircraft-2013b/fgvc-aircraft-2013b/data/images/1288666.jpg
#   inflating: /content/dataset/fgvc-aircraft-2013b/fgvc-aircraft-2013b/data/images/1288668.jpg
#   inflating: /content/dataset/fgvc-aircraft-2013b/fgvc-aircraft-2013b/data/images/1288673.jpg
#   inflating: /content/dataset/fgvc-aircraft-2013b/fgvc-aircraft-2013b/data/images/1288743.jpg
#   inflating: /content/dataset/fgvc-aircraft-2013b/fgvc-aircraft-2013b/data/images/1289187.jpg
#   inflating: /content/dataset/fgvc-aircraft-2013b/fgvc-aircraft-2013b/data/images/1289636.jpg
#   inflating: /content/dataset/fgvc-aircraft-2013b/fgvc-aircraft-2013b/data/images/1289638.jpg
#   inflating: /content/dataset/fgvc-aircraft-2013b/fgvc-aircraft-2013b/data/images/1289663.jpg
#   inflating: /content/dataset/fgvc-aircraft-2013b/fgvc-aircraft-2013b/data/images/1290539.jpg
#   inflating: /content/dataset/fgvc-aircraft-2013b/fgvc-aircraft-2013b/data/images/1290785.jpg
#   inflating: /content/dataset/fgvc-aircraft-2013b/fgvc-aircraft-2013b/data/images/1290983.jpg
#   inflating: /content/dataset/fgvc-aircraft-2013b/fgvc-aircraft-2013b/data/images/1290986.jpg
#   inflating: /content/dataset/fgvc-aircraft-2013b/fgvc-aircraft-2013b/data/images/1291069.jpg
#   inflating: /content/dataset/fgvc-aircraft-2013b/fgvc-aircraft-2013b/data/images/1291080.jpg
#   inflating: /content/dataset/fgvc-aircraft-2013b/fgvc-aircraft-2013b/data/images/1291092.jpg
#   inflating: /content/dataset/fgvc-aircraft-2013b/fgvc-aircraft-2013b/data/images/1291218.jpg
#   inflating: /content/dataset/fgvc-aircraft-2013b/fgvc-aircraft-2013b/data/images/1291233.jpg
#   inflating: /content/dataset/fgvc-aircraft-2013b/fgvc-aircraft-2013b/data/images/1291351.jpg
#   inflating: /content/dataset/fgvc-aircraft-2013b/fgvc-aircraft-2013b/data/images/1291370.jpg
#   inflating: /content/dataset/fgvc-aircraft-2013b/fgvc-aircraft-2013b/data/images/1291373.jpg
#   inflating: /content/dataset/fgvc-aircraft-2013b/fgvc-aircraft-2013b/data/images/1291783.jpg
#   inflating: /content/dataset/fgvc-aircraft-2013b/fgvc-aircraft-2013b/data/images/1291802.jpg
#   inflating: /content/dataset/fgvc-aircraft-2013b/fgvc-aircraft-2013b/data/images/1291894.jpg
#   inflating: /content/dataset/fgvc-aircraft-2013b/fgvc-aircraft-2013b/data/images/1291917.jpg
#   inflating: /content/dataset/fgvc-aircraft-2013b/fgvc-aircraft-2013b/data/images/1291973.jpg
#   inflating: /content/dataset/fgvc-aircraft-2013b/fgvc-aircraft-2013b/data/images/1292174.jpg
#   inflating: /content/dataset/fgvc-aircraft-2013b/fgvc-aircraft-2013b/data/images/1292176.jpg
#   inflating: /content/dataset/fgvc-aircraft-2013b/fgvc-aircraft-2013b/data/images/1292318.jpg
#   inflating: /content/dataset/fgvc-aircraft-2013b/fgvc-aircraft-2013b/data/images/1292321.jpg
#   inflating: /content/dataset/fgvc-aircraft-2013b/fgvc-aircraft-2013b/data/images/1292370.jpg
#   inflating: /content/dataset/fgvc-aircraft-2013b/fgvc-aircraft-2013b/data/images/1292378.jpg
#   inflating: /content/dataset/fgvc-aircraft-2013b/fgvc-aircraft-2013b/data/images/1292386.jpg
#   inflating: /content/dataset/fgvc-aircraft-2013b/fgvc-aircraft-2013b/data/images/1292389.jpg
#   inflating: /content/dataset/fgvc-aircraft-2013b/fgvc-aircraft-2013b/data/images/1292390.jpg
#   inflating: /content/dataset/fgvc-aircraft-2013b/fgvc-aircraft-2013b/data/images/1292392.jpg
#   inflating: /content/dataset/fgvc-aircraft-2013b/fgvc-aircraft-2013b/data/images/1292533.jpg
#   inflating: /content/dataset/fgvc-aircraft-2013b/fgvc-aircraft-2013b/data/images/1293019.jpg
#   inflating: /content/dataset/fgvc-aircraft-2013b/fgvc-aircraft-2013b/data/images/1293223.jpg
#   inflating: /content/dataset/fgvc-aircraft-2013b/fgvc-aircraft-2013b/data/images/1293480.jpg
#   inflating: /content/dataset/fgvc-aircraft-2013b/fgvc-aircraft-2013b/data/images/1293682.jpg
#   inflating: /content/dataset/fgvc-aircraft-2013b/fgvc-aircraft-2013b/data/images/1294490.jpg
#   inflating: /content/dataset/fgvc-aircraft-2013b/fgvc-aircraft-2013b/data/images/1294492.jpg
#   inflating: /content/dataset/fgvc-aircraft-2013b/fgvc-aircraft-2013b/data/images/1294505.jpg
#   inflating: /content/dataset/fgvc-aircraft-2013b/fgvc-aircraft-2013b/data/images/1294506.jpg
#   inflating: /content/dataset/fgvc-aircraft-2013b/fgvc-aircraft-2013b/data/images/1294569.jpg
#   inflating: /content/dataset/fgvc-aircraft-2013b/fgvc-aircraft-2013b/data/images/1295011.jpg
#   inflating: /content/dataset/fgvc-aircraft-2013b/fgvc-aircraft-2013b/data/images/1295495.jpg
#   inflating: /content/dataset/fgvc-aircraft-2013b/fgvc-aircraft-2013b/data/images/1295641.jpg
#   inflating: /content/dataset/fgvc-aircraft-2013b/fgvc-aircraft-2013b/data/images/1295646.jpg
#   inflating: /content/dataset/fgvc-aircraft-2013b/fgvc-aircraft-2013b/data/images/1295799.jpg
#   inflating: /content/dataset/fgvc-aircraft-2013b/fgvc-aircraft-2013b/data/images/1295999.jpg
#   inflating: /content/dataset/fgvc-aircraft-2013b/fgvc-aircraft-2013b/data/images/1296002.jpg
#   inflating: /content/dataset/fgvc-aircraft-2013b/fgvc-aircraft-2013b/data/images/1296186.jpg
#   inflating: /content/dataset/fgvc-aircraft-2013b/fgvc-aircraft-2013b/data/images/1296189.jpg
#   inflating: /content/dataset/fgvc-aircraft-2013b/fgvc-aircraft-2013b/data/images/1296201.jpg
#   inflating: /content/dataset/fgvc-aircraft-2013b/fgvc-aircraft-2013b/data/images/1296212.jpg
#   inflating: /content/dataset/fgvc-aircraft-2013b/fgvc-aircraft-2013b/data/images/1296245.jpg
#   inflating: /content/dataset/fgvc-aircraft-2013b/fgvc-aircraft-2013b/data/images/1296417.jpg
#   inflating: /content/dataset/fgvc-aircraft-2013b/fgvc-aircraft-2013b/data/images/1296580.jpg
#   inflating: /content/dataset/fgvc-aircraft-2013b/fgvc-aircraft-2013b/data/images/1296582.jpg
#   inflating: /content/dataset/fgvc-aircraft-2013b/fgvc-aircraft-2013b/data/images/1296822.jpg
#   inflating: /content/dataset/fgvc-aircraft-2013b/fgvc-aircraft-2013b/data/images/1296833.jpg
#   inflating: /content/dataset/fgvc-aircraft-2013b/fgvc-aircraft-2013b/data/images/1296872.jpg
#   inflating: /content/dataset/fgvc-aircraft-2013b/fgvc-aircraft-2013b/data/images/1296886.jpg
#   inflating: /content/dataset/fgvc-aircraft-2013b/fgvc-aircraft-2013b/data/images/1296896.jpg
#   inflating: /content/dataset/fgvc-aircraft-2013b/fgvc-aircraft-2013b/data/images/1296897.jpg
#   inflating: /content/dataset/fgvc-aircraft-2013b/fgvc-aircraft-2013b/data/images/1296938.jpg
#   inflating: /content/dataset/fgvc-aircraft-2013b/fgvc-aircraft-2013b/data/images/1296939.jpg
#   inflating: /content/dataset/fgvc-aircraft-2013b/fgvc-aircraft-2013b/data/images/1296942.jpg
#   inflating: /content/dataset/fgvc-aircraft-2013b/fgvc-aircraft-2013b/data/images/1297059.jpg
#   inflating: /content/dataset/fgvc-aircraft-2013b/fgvc-aircraft-2013b/data/images/1297523.jpg
#   inflating: /content/dataset/fgvc-aircraft-2013b/fgvc-aircraft-2013b/data/images/1297843.jpg
#   inflating: /content/dataset/fgvc-aircraft-2013b/fgvc-aircraft-2013b/data/images/1298145.jpg
#   inflating: /content/dataset/fgvc-aircraft-2013b/fgvc-aircraft-2013b/data/images/1298308.jpg
#   inflating: /content/dataset/fgvc-aircraft-2013b/fgvc-aircraft-2013b/data/images/1298374.jpg
#   inflating: /content/dataset/fgvc-aircraft-2013b/fgvc-aircraft-2013b/data/images/1298765.jpg
#   inflating: /content/dataset/fgvc-aircraft-2013b/fgvc-aircraft-2013b/data/images/1298772.jpg
#   inflating: /content/dataset/fgvc-aircraft-2013b/fgvc-aircraft-2013b/data/images/1298901.jpg
#   inflating: /content/dataset/fgvc-aircraft-2013b/fgvc-aircraft-2013b/data/images/1298905.jpg
#   inflating: /content/dataset/fgvc-aircraft-2013b/fgvc-aircraft-2013b/data/images/1298910.jpg
#   inflating: /content/dataset/fgvc-aircraft-2013b/fgvc-aircraft-2013b/data/images/1298911.jpg
#   inflating: /content/dataset/fgvc-aircraft-2013b/fgvc-aircraft-2013b/data/images/1298912.jpg
#   inflating: /content/dataset/fgvc-aircraft-2013b/fgvc-aircraft-2013b/data/images/1298949.jpg
#   inflating: /content/dataset/fgvc-aircraft-2013b/fgvc-aircraft-2013b/data/images/1298958.jpg
#   inflating: /content/dataset/fgvc-aircraft-2013b/fgvc-aircraft-2013b/data/images/1299189.jpg
#   inflating: /content/dataset/fgvc-aircraft-2013b/fgvc-aircraft-2013b/data/images/1299225.jpg
#   inflating: /content/dataset/fgvc-aircraft-2013b/fgvc-aircraft-2013b/data/images/1299226.jpg
#   inflating: /content/dataset/fgvc-aircraft-2013b/fgvc-aircraft-2013b/data/images/1299601.jpg
#   inflating: /content/dataset/fgvc-aircraft-2013b/fgvc-aircraft-2013b/data/images/1299912.jpg
#   inflating: /content/dataset/fgvc-aircraft-2013b/fgvc-aircraft-2013b/data/images/1299913.jpg
#   inflating: /content/dataset/fgvc-aircraft-2013b/fgvc-aircraft-2013b/data/images/1299978.jpg
#   inflating: /content/dataset/fgvc-aircraft-2013b/fgvc-aircraft-2013b/data/images/1299986.jpg
#   inflating: /content/dataset/fgvc-aircraft-2013b/fgvc-aircraft-2013b/data/images/1300002.jpg
#   inflating: /content/dataset/fgvc-aircraft-2013b/fgvc-aircraft-2013b/data/images/1300106.jpg
#   inflating: /content/dataset/fgvc-aircraft-2013b/fgvc-aircraft-2013b/data/images/1300481.jpg
#   inflating: /content/dataset/fgvc-aircraft-2013b/fgvc-aircraft-2013b/data/images/1300487.jpg
#   inflating: /content/dataset/fgvc-aircraft-2013b/fgvc-aircraft-2013b/data/images/1301856.jpg
#   inflating: /content/dataset/fgvc-aircraft-2013b/fgvc-aircraft-2013b/data/images/1302049.jpg
#   inflating: /content/dataset/fgvc-aircraft-2013b/fgvc-aircraft-2013b/data/images/1302093.jpg
#   inflating: /content/dataset/fgvc-aircraft-2013b/fgvc-aircraft-2013b/data/images/1302570.jpg
#   inflating: /content/dataset/fgvc-aircraft-2013b/fgvc-aircraft-2013b/data/images/1302677.jpg
#   inflating: /content/dataset/fgvc-aircraft-2013b/fgvc-aircraft-2013b/data/images/1302750.jpg
#   inflating: /content/dataset/fgvc-aircraft-2013b/fgvc-aircraft-2013b/data/images/1302786.jpg
#   inflating: /content/dataset/fgvc-aircraft-2013b/fgvc-aircraft-2013b/data/images/1302842.jpg
#   inflating: /content/dataset/fgvc-aircraft-2013b/fgvc-aircraft-2013b/data/images/1302868.jpg
#   inflating: /content/dataset/fgvc-aircraft-2013b/fgvc-aircraft-2013b/data/images/1302871.jpg
#   inflating: /content/dataset/fgvc-aircraft-2013b/fgvc-aircraft-2013b/data/images/1302926.jpg
#   inflating: /content/dataset/fgvc-aircraft-2013b/fgvc-aircraft-2013b/data/images/1303402.jpg
#   inflating: /content/dataset/fgvc-aircraft-2013b/fgvc-aircraft-2013b/data/images/1303460.jpg
#   inflating: /content/dataset/fgvc-aircraft-2013b/fgvc-aircraft-2013b/data/images/1303532.jpg
#   inflating: /content/dataset/fgvc-aircraft-2013b/fgvc-aircraft-2013b/data/images/1303850.jpg
#   inflating: /content/dataset/fgvc-aircraft-2013b/fgvc-aircraft-2013b/data/images/1303941.jpg
#   inflating: /content/dataset/fgvc-aircraft-2013b/fgvc-aircraft-2013b/data/images/1303943.jpg
#   inflating: /content/dataset/fgvc-aircraft-2013b/fgvc-aircraft-2013b/data/images/1303982.jpg
#   inflating: /content/dataset/fgvc-aircraft-2013b/fgvc-aircraft-2013b/data/images/1304025.jpg
#   inflating: /content/dataset/fgvc-aircraft-2013b/fgvc-aircraft-2013b/data/images/1304093.jpg
#   inflating: /content/dataset/fgvc-aircraft-2013b/fgvc-aircraft-2013b/data/images/1304098.jpg
#   inflating: /content/dataset/fgvc-aircraft-2013b/fgvc-aircraft-2013b/data/images/1304344.jpg
#   inflating: /content/dataset/fgvc-aircraft-2013b/fgvc-aircraft-2013b/data/images/1304869.jpg
#   inflating: /content/dataset/fgvc-aircraft-2013b/fgvc-aircraft-2013b/data/images/1304878.jpg
#   inflating: /content/dataset/fgvc-aircraft-2013b/fgvc-aircraft-2013b/data/images/1305520.jpg
#   inflating: /content/dataset/fgvc-aircraft-2013b/fgvc-aircraft-2013b/data/images/1305611.jpg
#   inflating: /content/dataset/fgvc-aircraft-2013b/fgvc-aircraft-2013b/data/images/1305614.jpg
#   inflating: /content/dataset/fgvc-aircraft-2013b/fgvc-aircraft-2013b/data/images/1305696.jpg
#   inflating: /content/dataset/fgvc-aircraft-2013b/fgvc-aircraft-2013b/data/images/1305905.jpg
#   inflating: /content/dataset/fgvc-aircraft-2013b/fgvc-aircraft-2013b/data/images/1306316.jpg
#   inflating: /content/dataset/fgvc-aircraft-2013b/fgvc-aircraft-2013b/data/images/1306689.jpg
#   inflating: /content/dataset/fgvc-aircraft-2013b/fgvc-aircraft-2013b/data/images/1306976.jpg
#   inflating: /content/dataset/fgvc-aircraft-2013b/fgvc-aircraft-2013b/data/images/1307073.jpg
#   inflating: /content/dataset/fgvc-aircraft-2013b/fgvc-aircraft-2013b/data/images/1307230.jpg
#   inflating: /content/dataset/fgvc-aircraft-2013b/fgvc-aircraft-2013b/data/images/1307278.jpg
#   inflating: /content/dataset/fgvc-aircraft-2013b/fgvc-aircraft-2013b/data/images/1307312.jpg
#   inflating: /content/dataset/fgvc-aircraft-2013b/fgvc-aircraft-2013b/data/images/1307327.jpg
#   inflating: /content/dataset/fgvc-aircraft-2013b/fgvc-aircraft-2013b/data/images/1307362.jpg
#   inflating: /content/dataset/fgvc-aircraft-2013b/fgvc-aircraft-2013b/data/images/1307364.jpg
#   inflating: /content/dataset/fgvc-aircraft-2013b/fgvc-aircraft-2013b/data/images/1307574.jpg
#   inflating: /content/dataset/fgvc-aircraft-2013b/fgvc-aircraft-2013b/data/images/1307739.jpg
#   inflating: /content/dataset/fgvc-aircraft-2013b/fgvc-aircraft-2013b/data/images/1308267.jpg
#   inflating: /content/dataset/fgvc-aircraft-2013b/fgvc-aircraft-2013b/data/images/1308317.jpg
#   inflating: /content/dataset/fgvc-aircraft-2013b/fgvc-aircraft-2013b/data/images/1308386.jpg
#   inflating: /content/dataset/fgvc-aircraft-2013b/fgvc-aircraft-2013b/data/images/1308404.jpg
#   inflating: /content/dataset/fgvc-aircraft-2013b/fgvc-aircraft-2013b/data/images/1308524.jpg
#   inflating: /content/dataset/fgvc-aircraft-2013b/fgvc-aircraft-2013b/data/images/1309052.jpg
#   inflating: /content/dataset/fgvc-aircraft-2013b/fgvc-aircraft-2013b/data/images/1309306.jpg
#   inflating: /content/dataset/fgvc-aircraft-2013b/fgvc-aircraft-2013b/data/images/1310046.jpg
#   inflating: /content/dataset/fgvc-aircraft-2013b/fgvc-aircraft-2013b/data/images/1310123.jpg
#   inflating: /content/dataset/fgvc-aircraft-2013b/fgvc-aircraft-2013b/data/images/1310548.jpg
#   inflating: /content/dataset/fgvc-aircraft-2013b/fgvc-aircraft-2013b/data/images/1310734.jpg
#   inflating: /content/dataset/fgvc-aircraft-2013b/fgvc-aircraft-2013b/data/images/1310900.jpg
#   inflating: /content/dataset/fgvc-aircraft-2013b/fgvc-aircraft-2013b/data/images/1311406.jpg
#   inflating: /content/dataset/fgvc-aircraft-2013b/fgvc-aircraft-2013b/data/images/1311419.jpg
#   inflating: /content/dataset/fgvc-aircraft-2013b/fgvc-aircraft-2013b/data/images/1311421.jpg
#   inflating: /content/dataset/fgvc-aircraft-2013b/fgvc-aircraft-2013b/data/images/1311582.jpg
#   inflating: /content/dataset/fgvc-aircraft-2013b/fgvc-aircraft-2013b/data/images/1311585.jpg
#   inflating: /content/dataset/fgvc-aircraft-2013b/fgvc-aircraft-2013b/data/images/1311620.jpg
#   inflating: /content/dataset/fgvc-aircraft-2013b/fgvc-aircraft-2013b/data/images/1311978.jpg
#   inflating: /content/dataset/fgvc-aircraft-2013b/fgvc-aircraft-2013b/data/images/1311998.jpg
#   inflating: /content/dataset/fgvc-aircraft-2013b/fgvc-aircraft-2013b/data/images/1312101.jpg
#   inflating: /content/dataset/fgvc-aircraft-2013b/fgvc-aircraft-2013b/data/images/1312250.jpg
#   inflating: /content/dataset/fgvc-aircraft-2013b/fgvc-aircraft-2013b/data/images/1312387.jpg
#   inflating: /content/dataset/fgvc-aircraft-2013b/fgvc-aircraft-2013b/data/images/1312418.jpg
#   inflating: /content/dataset/fgvc-aircraft-2013b/fgvc-aircraft-2013b/data/images/1312496.jpg
#   inflating: /content/dataset/fgvc-aircraft-2013b/fgvc-aircraft-2013b/data/images/1312504.jpg
#   inflating: /content/dataset/fgvc-aircraft-2013b/fgvc-aircraft-2013b/data/images/1312508.jpg
#   inflating: /content/dataset/fgvc-aircraft-2013b/fgvc-aircraft-2013b/data/images/1312509.jpg
#   inflating: /content/dataset/fgvc-aircraft-2013b/fgvc-aircraft-2013b/data/images/1312518.jpg
#   inflating: /content/dataset/fgvc-aircraft-2013b/fgvc-aircraft-2013b/data/images/1312523.jpg
#   inflating: /content/dataset/fgvc-aircraft-2013b/fgvc-aircraft-2013b/data/images/1312536.jpg
#   inflating: /content/dataset/fgvc-aircraft-2013b/fgvc-aircraft-2013b/data/images/1312740.jpg
#   inflating: /content/dataset/fgvc-aircraft-2013b/fgvc-aircraft-2013b/data/images/1312743.jpg
#   inflating: /content/dataset/fgvc-aircraft-2013b/fgvc-aircraft-2013b/data/images/1312876.jpg
#   inflating: /content/dataset/fgvc-aircraft-2013b/fgvc-aircraft-2013b/data/images/1312882.jpg
#   inflating: /content/dataset/fgvc-aircraft-2013b/fgvc-aircraft-2013b/data/images/1313042.jpg
#   inflating: /content/dataset/fgvc-aircraft-2013b/fgvc-aircraft-2013b/data/images/1313048.jpg
#   inflating: /content/dataset/fgvc-aircraft-2013b/fgvc-aircraft-2013b/data/images/1313184.jpg
#   inflating: /content/dataset/fgvc-aircraft-2013b/fgvc-aircraft-2013b/data/images/1313225.jpg
#   inflating: /content/dataset/fgvc-aircraft-2013b/fgvc-aircraft-2013b/data/images/1313340.jpg
#   inflating: /content/dataset/fgvc-aircraft-2013b/fgvc-aircraft-2013b/data/images/1313344.jpg
#   inflating: /content/dataset/fgvc-aircraft-2013b/fgvc-aircraft-2013b/data/images/1313348.jpg
#   inflating: /content/dataset/fgvc-aircraft-2013b/fgvc-aircraft-2013b/data/images/1313354.jpg
#   inflating: /content/dataset/fgvc-aircraft-2013b/fgvc-aircraft-2013b/data/images/1313522.jpg
#   inflating: /content/dataset/fgvc-aircraft-2013b/fgvc-aircraft-2013b/data/images/1313523.jpg
#   inflating: /content/dataset/fgvc-aircraft-2013b/fgvc-aircraft-2013b/data/images/1313666.jpg
#   inflating: /content/dataset/fgvc-aircraft-2013b/fgvc-aircraft-2013b/data/images/1313682.jpg
#   inflating: /content/dataset/fgvc-aircraft-2013b/fgvc-aircraft-2013b/data/images/1313891.jpg
#   inflating: /content/dataset/fgvc-aircraft-2013b/fgvc-aircraft-2013b/data/images/1313993.jpg
#   inflating: /content/dataset/fgvc-aircraft-2013b/fgvc-aircraft-2013b/data/images/1314034.jpg
#   inflating: /content/dataset/fgvc-aircraft-2013b/fgvc-aircraft-2013b/data/images/1314181.jpg
#   inflating: /content/dataset/fgvc-aircraft-2013b/fgvc-aircraft-2013b/data/images/1314535.jpg
#   inflating: /content/dataset/fgvc-aircraft-2013b/fgvc-aircraft-2013b/data/images/1314561.jpg
#   inflating: /content/dataset/fgvc-aircraft-2013b/fgvc-aircraft-2013b/data/images/1314595.jpg
#   inflating: /content/dataset/fgvc-aircraft-2013b/fgvc-aircraft-2013b/data/images/1314986.jpg
#   inflating: /content/dataset/fgvc-aircraft-2013b/fgvc-aircraft-2013b/data/images/1314987.jpg
#   inflating: /content/dataset/fgvc-aircraft-2013b/fgvc-aircraft-2013b/data/images/1315041.jpg
#   inflating: /content/dataset/fgvc-aircraft-2013b/fgvc-aircraft-2013b/data/images/1315140.jpg
#   inflating: /content/dataset/fgvc-aircraft-2013b/fgvc-aircraft-2013b/data/images/1315141.jpg
# ...
#   inflating: /content/dataset/fgvc-aircraft-2013b/fgvc-aircraft-2013b/data/images/2236360.jpg
#   inflating: /content/dataset/fgvc-aircraft-2013b/fgvc-aircraft-2013b/data/images/2236389.jpg
#   inflating: /content/dataset/fgvc-aircraft-2013b/fgvc-aircraft-2013b/data/images/2236391.jpg
#   inflating: /content/dataset/fgvc-aircraft-2013b/fgvc-aircraft-2013b/data/images/2236569.jpg
#   inflating: /content/dataset/fgvc-aircraft-2013b/fgvc-aircraft-2013b/data/images/2236758.jpg
#   inflating: /content/dataset/fgvc-aircraft-2013b/fgvc-aircraft-2013b/data/images/2236962.jpg
#   inflating: /content/dataset/fgvc-aircraft-2013b/fgvc-aircraft-2013b/data/images/2236964.jpg
#   inflating: /content/dataset/fgvc-aircraft-2013b/fgvc-aircraft-2013b/data/images/2236966.jpg
#   inflating: /content/dataset/fgvc-aircraft-2013b/fgvc-aircraft-2013b/data/images/2236969.jpg
#   inflating: /content/dataset/fgvc-aircraft-2013b/fgvc-aircraft-2013b/data/images/2236971.jpg
#   inflating: /content/dataset/fgvc-aircraft-2013b/fgvc-aircraft-2013b/data/images/2237178.jpg
#   inflating: /content/dataset/fgvc-aircraft-2013b/fgvc-aircraft-2013b/data/images/2238327.jpg
#   inflating: /content/dataset/fgvc-aircraft-2013b/fgvc-aircraft-2013b/data/images/2238330.jpg
#   inflating: /content/dataset/fgvc-aircraft-2013b/fgvc-aircraft-2013b/data/images/2238661.jpg
#   inflating: /content/dataset/fgvc-aircraft-2013b/fgvc-aircraft-2013b/data/images/2239066.jpg
#   inflating: /content/dataset/fgvc-aircraft-2013b/fgvc-aircraft-2013b/data/images/2239287.jpg
#   inflating: /content/dataset/fgvc-aircraft-2013b/fgvc-aircraft-2013b/data/images/2239290.jpg
#   inflating: /content/dataset/fgvc-aircraft-2013b/fgvc-aircraft-2013b/data/images/2239292.jpg
#   inflating: /content/dataset/fgvc-aircraft-2013b/fgvc-aircraft-2013b/data/images/2239296.jpg
#   inflating: /content/dataset/fgvc-aircraft-2013b/fgvc-aircraft-2013b/data/images/2239298.jpg
#   inflating: /content/dataset/fgvc-aircraft-2013b/fgvc-aircraft-2013b/data/images/2239301.jpg
#   inflating: /content/dataset/fgvc-aircraft-2013b/fgvc-aircraft-2013b/data/images/2239584.jpg
#   inflating: /content/dataset/fgvc-aircraft-2013b/fgvc-aircraft-2013b/data/images/2239587.jpg
#   inflating: /content/dataset/fgvc-aircraft-2013b/fgvc-aircraft-2013b/data/images/2239589.jpg
#   inflating: /content/dataset/fgvc-aircraft-2013b/fgvc-aircraft-2013b/data/images/2239590.jpg
#   inflating: /content/dataset/fgvc-aircraft-2013b/fgvc-aircraft-2013b/data/images/2239626.jpg
#   inflating: /content/dataset/fgvc-aircraft-2013b/fgvc-aircraft-2013b/data/images/2239630.jpg
#   inflating: /content/dataset/fgvc-aircraft-2013b/fgvc-aircraft-2013b/data/images/2239753.jpg
#   inflating: /content/dataset/fgvc-aircraft-2013b/fgvc-aircraft-2013b/data/images/2239815.jpg
#   inflating: /content/dataset/fgvc-aircraft-2013b/fgvc-aircraft-2013b/data/images/2239816.jpg
#   inflating: /content/dataset/fgvc-aircraft-2013b/fgvc-aircraft-2013b/data/images/2240083.jpg
#   inflating: /content/dataset/fgvc-aircraft-2013b/fgvc-aircraft-2013b/data/images/2240254.jpg
#   inflating: /content/dataset/fgvc-aircraft-2013b/fgvc-aircraft-2013b/data/images/2240720.jpg
#   inflating: /content/dataset/fgvc-aircraft-2013b/fgvc-aircraft-2013b/data/images/2241501.jpg
#   inflating: /content/dataset/fgvc-aircraft-2013b/fgvc-aircraft-2013b/data/images/2241569.jpg
#   inflating: /content/dataset/fgvc-aircraft-2013b/fgvc-aircraft-2013b/data/images/2241970.jpg
#   inflating: /content/dataset/fgvc-aircraft-2013b/fgvc-aircraft-2013b/data/images/2241971.jpg
#   inflating: /content/dataset/fgvc-aircraft-2013b/fgvc-aircraft-2013b/data/images/2242332.jpg
#   inflating: /content/dataset/fgvc-aircraft-2013b/fgvc-aircraft-2013b/data/images/2243379.jpg
#   inflating: /content/dataset/fgvc-aircraft-2013b/fgvc-aircraft-2013b/data/images/2243380.jpg
#   inflating: /content/dataset/fgvc-aircraft-2013b/fgvc-aircraft-2013b/data/images/2243382.jpg
#   inflating: /content/dataset/fgvc-aircraft-2013b/fgvc-aircraft-2013b/data/images/2243568.jpg
#   inflating: /content/dataset/fgvc-aircraft-2013b/fgvc-aircraft-2013b/data/images/2243572.jpg
#   inflating: /content/dataset/fgvc-aircraft-2013b/fgvc-aircraft-2013b/data/images/2243578.jpg
#   inflating: /content/dataset/fgvc-aircraft-2013b/fgvc-aircraft-2013b/data/images/2243615.jpg
#   inflating: /content/dataset/fgvc-aircraft-2013b/fgvc-aircraft-2013b/data/images/2243783.jpg
#   inflating: /content/dataset/fgvc-aircraft-2013b/fgvc-aircraft-2013b/data/images/2243788.jpg
#   inflating: /content/dataset/fgvc-aircraft-2013b/fgvc-aircraft-2013b/data/images/2243949.jpg
#   inflating: /content/dataset/fgvc-aircraft-2013b/fgvc-aircraft-2013b/data/images/2243952.jpg
#   inflating: /content/dataset/fgvc-aircraft-2013b/fgvc-aircraft-2013b/data/images/2244063.jpg
#   inflating: /content/dataset/fgvc-aircraft-2013b/fgvc-aircraft-2013b/data/images/2244446.jpg
#   inflating: /content/dataset/fgvc-aircraft-2013b/fgvc-aircraft-2013b/data/images/2244487.jpg
#   inflating: /content/dataset/fgvc-aircraft-2013b/fgvc-aircraft-2013b/data/images/2244501.jpg
#   inflating: /content/dataset/fgvc-aircraft-2013b/fgvc-aircraft-2013b/data/images/2244548.jpg
#   inflating: /content/dataset/fgvc-aircraft-2013b/fgvc-aircraft-2013b/data/images/2244549.jpg
#   inflating: /content/dataset/fgvc-aircraft-2013b/fgvc-aircraft-2013b/data/images/2244649.jpg
#   inflating: /content/dataset/fgvc-aircraft-2013b/fgvc-aircraft-2013b/data/images/2244841.jpg
#   inflating: /content/dataset/fgvc-aircraft-2013b/fgvc-aircraft-2013b/data/images/2245398.jpg
#   inflating: /content/dataset/fgvc-aircraft-2013b/fgvc-aircraft-2013b/data/images/2245399.jpg
#   inflating: /content/dataset/fgvc-aircraft-2013b/fgvc-aircraft-2013b/data/images/2245655.jpg
#   inflating: /content/dataset/fgvc-aircraft-2013b/fgvc-aircraft-2013b/data/images/2245660.jpg
#   inflating: /content/dataset/fgvc-aircraft-2013b/fgvc-aircraft-2013b/data/images/2246105.jpg
#   inflating: /content/dataset/fgvc-aircraft-2013b/fgvc-aircraft-2013b/data/images/2246817.jpg
#   inflating: /content/dataset/fgvc-aircraft-2013b/fgvc-aircraft-2013b/data/images/2247106.jpg
#   inflating: /content/dataset/fgvc-aircraft-2013b/fgvc-aircraft-2013b/data/images/2247510.jpg
#   inflating: /content/dataset/fgvc-aircraft-2013b/fgvc-aircraft-2013b/data/images/2247793.jpg
#   inflating: /content/dataset/fgvc-aircraft-2013b/fgvc-aircraft-2013b/data/images/2247794.jpg
#   inflating: /content/dataset/fgvc-aircraft-2013b/fgvc-aircraft-2013b/data/images/2248561.jpg
#   inflating: /content/dataset/fgvc-aircraft-2013b/fgvc-aircraft-2013b/data/images/2248578.jpg
#   inflating: /content/dataset/fgvc-aircraft-2013b/fgvc-aircraft-2013b/data/images/2248581.jpg
#   inflating: /content/dataset/fgvc-aircraft-2013b/fgvc-aircraft-2013b/data/images/2248582.jpg
#   inflating: /content/dataset/fgvc-aircraft-2013b/fgvc-aircraft-2013b/data/images/2248661.jpg
#   inflating: /content/dataset/fgvc-aircraft-2013b/fgvc-aircraft-2013b/data/images/2248944.jpg
#   inflating: /content/dataset/fgvc-aircraft-2013b/fgvc-aircraft-2013b/data/images/2248958.jpg
#   inflating: /content/dataset/fgvc-aircraft-2013b/fgvc-aircraft-2013b/data/images/2249122.jpg
#   inflating: /content/dataset/fgvc-aircraft-2013b/fgvc-aircraft-2013b/data/images/2250798.jpg
#   inflating: /content/dataset/fgvc-aircraft-2013b/fgvc-aircraft-2013b/data/images/2250823.jpg
#   inflating: /content/dataset/fgvc-aircraft-2013b/fgvc-aircraft-2013b/data/images/2251068.jpg
#   inflating: /content/dataset/fgvc-aircraft-2013b/fgvc-aircraft-2013b/data/images/2251118.jpg
#   inflating: /content/dataset/fgvc-aircraft-2013b/fgvc-aircraft-2013b/data/images/2251120.jpg
#   inflating: /content/dataset/fgvc-aircraft-2013b/fgvc-aircraft-2013b/data/images/2251121.jpg
#   inflating: /content/dataset/fgvc-aircraft-2013b/fgvc-aircraft-2013b/data/images/2251230.jpg
#   inflating: /content/dataset/fgvc-aircraft-2013b/fgvc-aircraft-2013b/data/images/2251723.jpg
#   inflating: /content/dataset/fgvc-aircraft-2013b/fgvc-aircraft-2013b/data/images/2251900.jpg
#   inflating: /content/dataset/fgvc-aircraft-2013b/fgvc-aircraft-2013b/data/images/2251908.jpg
#   inflating: /content/dataset/fgvc-aircraft-2013b/fgvc-aircraft-2013b/data/images/2252347.jpg
#   inflating: /content/dataset/fgvc-aircraft-2013b/fgvc-aircraft-2013b/data/images/2252349.jpg
#   inflating: /content/dataset/fgvc-aircraft-2013b/fgvc-aircraft-2013b/data/images/2253091.jpg
#   inflating: /content/dataset/fgvc-aircraft-2013b/fgvc-aircraft-2013b/data/images/2253229.jpg
#   inflating: /content/dataset/fgvc-aircraft-2013b/fgvc-aircraft-2013b/data/images/2253635.jpg
#   inflating: /content/dataset/fgvc-aircraft-2013b/fgvc-aircraft-2013b/data/images/2254473.jpg
#   inflating: /content/dataset/fgvc-aircraft-2013b/fgvc-aircraft-2013b/data/images/2255569.jpg
#   inflating: /content/dataset/fgvc-aircraft-2013b/fgvc-aircraft-2013b/data/images/2255571.jpg
#   inflating: /content/dataset/fgvc-aircraft-2013b/fgvc-aircraft-2013b/data/images/2256413.jpg
#   inflating: /content/dataset/fgvc-aircraft-2013b/fgvc-aircraft-2013b/data/images/2256592.jpg
#   inflating: /content/dataset/fgvc-aircraft-2013b/fgvc-aircraft-2013b/data/images/2257341.jpg
#   inflating: /content/dataset/fgvc-aircraft-2013b/fgvc-aircraft-2013b/data/images/2258288.jpg
#   inflating: /content/dataset/fgvc-aircraft-2013b/fgvc-aircraft-2013b/data/images/2258360.jpg
#   inflating: /content/dataset/fgvc-aircraft-2013b/fgvc-aircraft-2013b/data/images/2258768.jpg
#   inflating: /content/dataset/fgvc-aircraft-2013b/fgvc-aircraft-2013b/data/images/2258769.jpg
#   inflating: /content/dataset/fgvc-aircraft-2013b/fgvc-aircraft-2013b/data/images/2259021.jpg
#   inflating: /content/dataset/fgvc-aircraft-2013b/fgvc-aircraft-2013b/data/images/2259027.jpg
#   inflating: /content/dataset/fgvc-aircraft-2013b/fgvc-aircraft-2013b/data/images/2259104.jpg
#   inflating: /content/dataset/fgvc-aircraft-2013b/fgvc-aircraft-2013b/data/images/2259107.jpg
#   inflating: /content/dataset/fgvc-aircraft-2013b/fgvc-aircraft-2013b/data/images/2259257.jpg
#   inflating: /content/dataset/fgvc-aircraft-2013b/fgvc-aircraft-2013b/data/images/2259299.jpg
#   inflating: /content/dataset/fgvc-aircraft-2013b/fgvc-aircraft-2013b/data/images/2259451.jpg
#   inflating: /content/dataset/fgvc-aircraft-2013b/fgvc-aircraft-2013b/data/images/2259453.jpg
#   inflating: /content/dataset/fgvc-aircraft-2013b/fgvc-aircraft-2013b/data/images/2259583.jpg
#   inflating: /content/dataset/fgvc-aircraft-2013b/fgvc-aircraft-2013b/data/images/2259653.jpg
#   inflating: /content/dataset/fgvc-aircraft-2013b/fgvc-aircraft-2013b/data/images/2259663.jpg
#   inflating: /content/dataset/fgvc-aircraft-2013b/fgvc-aircraft-2013b/data/images/2259847.jpg
#   inflating: /content/dataset/fgvc-aircraft-2013b/fgvc-aircraft-2013b/data/images/2259848.jpg
#   inflating: /content/dataset/fgvc-aircraft-2013b/fgvc-aircraft-2013b/data/images/2259875.jpg
#   inflating: /content/dataset/fgvc-aircraft-2013b/fgvc-aircraft-2013b/data/images/2259876.jpg
#   inflating: /content/dataset/fgvc-aircraft-2013b/fgvc-aircraft-2013b/data/images/2259899.jpg
#   inflating: /content/dataset/fgvc-aircraft-2013b/fgvc-aircraft-2013b/data/images/2260054.jpg
#   inflating: /content/dataset/fgvc-aircraft-2013b/fgvc-aircraft-2013b/data/images/2260088.jpg
#   inflating: /content/dataset/fgvc-aircraft-2013b/fgvc-aircraft-2013b/data/images/2260089.jpg
#   inflating: /content/dataset/fgvc-aircraft-2013b/fgvc-aircraft-2013b/data/images/2260617.jpg
#   inflating: /content/dataset/fgvc-aircraft-2013b/fgvc-aircraft-2013b/data/images/2260732.jpg
#   inflating: /content/dataset/fgvc-aircraft-2013b/fgvc-aircraft-2013b/data/images/2260895.jpg
#   inflating: /content/dataset/fgvc-aircraft-2013b/fgvc-aircraft-2013b/data/images/2261957.jpg
#   inflating: /content/dataset/fgvc-aircraft-2013b/fgvc-aircraft-2013b/data/images/2262077.jpg
#   inflating: /content/dataset/fgvc-aircraft-2013b/fgvc-aircraft-2013b/data/images/2262511.jpg
#   inflating: /content/dataset/fgvc-aircraft-2013b/fgvc-aircraft-2013b/data/images/2262617.jpg
#   inflating: /content/dataset/fgvc-aircraft-2013b/fgvc-aircraft-2013b/data/images/2262727.jpg
#   inflating: /content/dataset/fgvc-aircraft-2013b/fgvc-aircraft-2013b/data/images/2263029.jpg
#   inflating: /content/dataset/fgvc-aircraft-2013b/fgvc-aircraft-2013b/data/images/2263166.jpg
#   inflating: /content/dataset/fgvc-aircraft-2013b/fgvc-aircraft-2013b/data/images/2263428.jpg
#   inflating: /content/dataset/fgvc-aircraft-2013b/fgvc-aircraft-2013b/data/images/2263603.jpg
#   inflating: /content/dataset/fgvc-aircraft-2013b/fgvc-aircraft-2013b/data/images/2264249.jpg
#   inflating: /content/dataset/fgvc-aircraft-2013b/fgvc-aircraft-2013b/data/images/2264793.jpg
#   inflating: /content/dataset/fgvc-aircraft-2013b/fgvc-aircraft-2013b/data/images/2264828.jpg
#   inflating: /content/dataset/fgvc-aircraft-2013b/fgvc-aircraft-2013b/data/images/2264968.jpg
#   inflating: /content/dataset/fgvc-aircraft-2013b/fgvc-aircraft-2013b/data/images/2265511.jpg
#   inflating: /content/dataset/fgvc-aircraft-2013b/fgvc-aircraft-2013b/data/images/2265625.jpg
#   inflating: /content/dataset/fgvc-aircraft-2013b/fgvc-aircraft-2013b/data/images/2266079.jpg
#   inflating: /content/dataset/fgvc-aircraft-2013b/fgvc-aircraft-2013b/data/images/2266334.jpg
#   inflating: /content/dataset/fgvc-aircraft-2013b/fgvc-aircraft-2013b/data/images/2266336.jpg
#   inflating: /content/dataset/fgvc-aircraft-2013b/fgvc-aircraft-2013b/data/images/2266584.jpg
#   inflating: /content/dataset/fgvc-aircraft-2013b/fgvc-aircraft-2013b/data/images_box.txt
#   inflating: /content/dataset/fgvc-aircraft-2013b/fgvc-aircraft-2013b/data/images_family_test.txt
#   inflating: /content/dataset/fgvc-aircraft-2013b/fgvc-aircraft-2013b/data/images_family_train.txt
#   inflating: /content/dataset/fgvc-aircraft-2013b/fgvc-aircraft-2013b/data/images_family_trainval.txt
#   inflating: /content/dataset/fgvc-aircraft-2013b/fgvc-aircraft-2013b/data/images_family_val.txt
#   inflating: /content/dataset/fgvc-aircraft-2013b/fgvc-aircraft-2013b/data/images_manufacturer_test.txt
#   inflating: /content/dataset/fgvc-aircraft-2013b/fgvc-aircraft-2013b/data/images_manufacturer_train.txt
#   inflating: /content/dataset/fgvc-aircraft-2013b/fgvc-aircraft-2013b/data/images_manufacturer_trainval.txt
#   inflating: /content/dataset/fgvc-aircraft-2013b/fgvc-aircraft-2013b/data/images_manufacturer_val.txt
#   inflating: /content/dataset/fgvc-aircraft-2013b/fgvc-aircraft-2013b/data/images_test.txt
#   inflating: /content/dataset/fgvc-aircraft-2013b/fgvc-aircraft-2013b/data/images_train.txt
#   inflating: /content/dataset/fgvc-aircraft-2013b/fgvc-aircraft-2013b/data/images_val.txt
#   inflating: /content/dataset/fgvc-aircraft-2013b/fgvc-aircraft-2013b/data/images_variant_test.txt
#   inflating: /content/dataset/fgvc-aircraft-2013b/fgvc-aircraft-2013b/data/images_variant_train.txt
#   inflating: /content/dataset/fgvc-aircraft-2013b/fgvc-aircraft-2013b/data/images_variant_trainval.txt
#   inflating: /content/dataset/fgvc-aircraft-2013b/fgvc-aircraft-2013b/data/images_variant_val.txt
#   inflating: /content/dataset/fgvc-aircraft-2013b/fgvc-aircraft-2013b/data/manufacturers.txt
#   inflating: /content/dataset/fgvc-aircraft-2013b/fgvc-aircraft-2013b/data/variants.txt
#   inflating: /content/dataset/fgvc-aircraft-2013b/fgvc-aircraft-2013b/evaluation.m
#   inflating: /content/dataset/fgvc-aircraft-2013b/fgvc-aircraft-2013b/example_evaluation.m
#   inflating: /content/dataset/fgvc-aircraft-2013b/fgvc-aircraft-2013b/vl_argparse.m
#   inflating: /content/dataset/fgvc-aircraft-2013b/fgvc-aircraft-2013b/vl_pr.m
#   inflating: /content/dataset/fgvc-aircraft-2013b/fgvc-aircraft-2013b/vl_roc.m
#   inflating: /content/dataset/fgvc-aircraft-2013b/fgvc-aircraft-2013b/vl_tpfp.m
#   inflating: /content/dataset/test.csv
#   inflating: /content/dataset/train.csv
#   inflating: /content/dataset/val.csv

# %%
import pandas as pd
from tensorflow.keras.preprocessing.image import ImageDataGenerator
from tensorflow.keras.preprocessing import image_dataset_from_directory
import os

# Define the path to the dataset
dataset_path = '/content/dataset'
image_path = '/content/dataset/fgvc-aircraft-2013b/fgvc-aircraft-2013b/data/images'


# Load CSV files
train_df = pd.read_csv(os.path.join(dataset_path, 'train.csv'))
val_df = pd.read_csv(os.path.join(dataset_path, 'val.csv'))
test_df = pd.read_csv(os.path.join(dataset_path, 'test.csv'))

# Add full image paths to DataFrames
train_df['filepath'] = train_df['filename'].apply(lambda x: os.path.join(image_path, x))
val_df['filepath'] = val_df['filename'].apply(lambda x: os.path.join(image_path, x))
test_df['filepath'] = test_df['filename'].apply(lambda x: os.path.join(image_path, x))

# Convert class labels to categorical
train_df['Labels'] = train_df['Labels'].astype(str)
val_df['Labels'] = val_df['Labels'].astype(str)
test_df['Labels'] = test_df['Labels'].astype(str)

# Image and Batch size
img_size = (448, 448)
batch_size = 32

# Function to load and preprocess images with augmentation for training
def load_and_augment_image(image_path, label):
    img = tf.io.read_file(image_path)
    img = tf.image.decode_jpeg(img, channels=3)
    img = img[:-12, :, :]  #Remove the black line on the bottom
    img = tf.image.resize(img, img_size) / 255.0  # Normalize

    # Apply Data Augmentation
    img = tf.image.random_flip_left_right(img)
    img = tf.image.random_brightness(img, max_delta=0.1)
    img = tf.image.random_contrast(img, lower=0.9, upper=1.1)
    img = tf.image.random_saturation(img, lower=0.9, upper=1.1)
    img = tf.image.random_hue(img, max_delta=0.01)

    # **Additional Transformations**
    #img = tf.image.random_crop(img, size=[200, 200, 3])  # ✅ Random Cropping (optional)
    #img = tf.image.resize(img, (224, 224))  # Resize Back

    return img, label

# Function to load images without augmentation for validation/testing
def load_image(image_path, label):
    img = tf.io.read_file(image_path)
    img = tf.image.decode_jpeg(img, channels=3)
    img = img[:-12, :, :]  # Remove the black line on the bottom
    img = tf.image.resize(img, img_size) / 255.0  # Normalize
    label = tf.reshape(label, [])
    return img, label

# Convert DataFrames to TensorFlow datasets
def dataframe_to_dataset(df, batch_size=batch_size, shuffle=True, augment=False):
    file_paths = df['filepath'].values
    labels = df['Labels'].astype('category').cat.codes.values  # Convert labels to numerical format
    dataset = tf.data.Dataset.from_tensor_slices((file_paths, labels))

    if augment:
        dataset = dataset.map(lambda x, y: load_and_augment_image(x, y), num_parallel_calls=tf.data.AUTOTUNE)
    else:
        dataset = dataset.map(lambda x, y: load_image(x, y), num_parallel_calls=tf.data.AUTOTUNE)

    if shuffle:
        dataset = dataset.shuffle(len(df))
    dataset = dataset.batch(batch_size, drop_remainder=True).prefetch(2)  # Ensure consistency
    return dataset

# Create datasets using tf.data pipeline with augmentation for training
train_airplane = dataframe_to_dataset(train_df, batch_size=batch_size, augment=True)
val_airplane = dataframe_to_dataset(val_df, batch_size=batch_size, shuffle=False, augment=False)
test_airplane = dataframe_to_dataset(test_df, batch_size=batch_size, shuffle=False, augment=False)

# %%
def relu6(x):
    return tf.nn.relu6(x)

def se_module(inputs, reduction=4):
    input_channels = inputs.shape[-1]
    reduced_channels = input_channels // reduction

    se = layers.GlobalAveragePooling2D()(inputs)
    se = layers.Reshape((1, 1, input_channels))(se)
    se = layers.Dense(reduced_channels, activation='relu')(se)
    se = layers.Dense(input_channels, activation='sigmoid')(se)
    return layers.multiply([inputs, se])

@tf.keras.utils.register_keras_serializable()
class StochasticDepth(tf.keras.layers.Layer):
    def __init__(self, drop_prob=0.2, **kwargs):
        super().__init__(**kwargs)
        self.drop_prob = drop_prob

    def call(self, inputs, training=None):
        if training:
            keep_prob = 1.0 - self.drop_prob
            batch_size = tf.shape(inputs)[0]
            random_tensor = keep_prob + tf.random.uniform([batch_size, 1, 1, 1], dtype=inputs.dtype)
            binary_tensor = tf.floor(random_tensor)  # Convert to 0 or 1
            return inputs * binary_tensor / keep_prob  # Scale for variance correction
        return inputs

def inverted_residual_block(inputs, expansion_factor, output_channels, stride, use_se=True, dropout_rate=0.15, drop_prob=0.2):
    input_channels = inputs.shape[-1]
    expanded_channels = input_channels * expansion_factor

    # Expansion Phase
    x = layers.Conv2D(expanded_channels, kernel_size=1, padding='same', use_bias=False)(inputs)
    x = layers.Activation("relu6")(x)
    x = layers.BatchNormalization()(x)

    # Depthwise Convolution
    x = layers.DepthwiseConv2D(kernel_size=3, strides=stride, padding='same', use_bias=False)(x)
    x = layers.Activation("relu6")(x)
    x = layers.BatchNormalization()(x)

    # Squeeze-and-Excitation Module (Optional)
    if use_se:
        x = se_module(x)

    # Dropout to reduce overfitting
    x = layers.Dropout(dropout_rate)(x)

    # Projection Phase
    x = layers.Conv2D(output_channels, kernel_size=1, padding='same', use_bias=False, kernel_regularizer=l2(1e-4))(x)
    x = layers.BatchNormalization()(x)

    # ✅ Apply Stochastic Depth before residual connection
    x = StochasticDepth(drop_prob=drop_prob)(x)

    # Residual Connection
    if stride == 1 and input_channels == output_channels:
        x = layers.add([inputs, x])

    return x

from tensorflow.keras import layers

def residual_block(inputs, output_channels, stride=1, use_se=True, dropout_rate=0.15, drop_prob=0.2):
    input_channels = inputs.shape[-1]

    # First Convolution
    x = layers.Conv2D(output_channels, kernel_size=3, strides=stride, padding='same', use_bias=False)(inputs)
    x = layers.BatchNormalization()(x)
    x = layers.ReLU()(x)

    # Second Convolution
    x = layers.Conv2D(output_channels, kernel_size=3, padding='same', use_bias=False)(x)
    x = layers.BatchNormalization()(x)

    # Squeeze-and-Excitation Module (Optional)
    if use_se:
        x = se_module(x)

    # Dropout to reduce overfitting
    x = layers.Dropout(dropout_rate)(x)

    # Apply Stochastic Depth before residual connection
    x = StochasticDepth(drop_prob=drop_prob)(x)

    # Residual Connection
    if stride == 1 and input_channels == output_channels:
        x = layers.add([inputs, x])

    return x

def scale_parameters(base_depth, base_width, phi, alpha=1.2, beta=1.1, gamma=1.15):
    depth = int(base_depth * alpha ** phi)
    width = int(base_width * beta ** phi)
    return depth, width

from tensorflow.keras.regularizers import l2

def build_scaled_model(phi, input_shape=(448,448, 3), num_classes=6):
    base_depth = 4   # Number of IR blocks per stage
    base_width = 72  # Initial number of filters

    depth, width = scale_parameters(base_depth, base_width, phi)

    inputs = layers.Input(shape=(448,448,3))

    # Initial Conv Layer
    x = layers.Conv2D(width, kernel_size=3, strides=2, padding='same', use_bias=False)(inputs)
    x = layers.Activation("relu6")(x)
    x = layers.BatchNormalization()(x)

    # Stacking Inverted Residual Blocks with Scaling & Stochastic Depth
    for i in range(depth):
        stride = 1 if i > 0 else 2  # Stride 2 for first block in each stage
        drop_prob = min(0.05 + (0.02 * i), 0.2)
        x = residual_block(x,
                           #expansion_factor=4,
                           output_channels=width,
                           stride=stride,
                           use_se=True,
                           drop_prob=drop_prob)
        width *= 2  # Increase filters at each stage

    # Final Global Pooling and Classifier
    x = layers.GlobalAveragePooling2D()(x)
    x = layers.Dense(num_classes, activation='softmax')(x)

    model = tf.keras.Model(inputs, x)
    return model

# %%
small_model = build_scaled_model(phi=0)  # Small
small_model.summary()
print(len(small_model.layers))
# Out:
# Model: "functional"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┓
# ┃ Layer (type)              ┃ Output Shape           ┃        Param # ┃ Connected to           ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━┩
# │ input_layer (InputLayer)  │ (None, 448, 448, 3)    │              0 │ -                      │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ conv2d (Conv2D)           │ (None, 224, 224, 72)   │          1,944 │ input_layer[0][0]      │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ activation (Activation)   │ (None, 224, 224, 72)   │              0 │ conv2d[0][0]           │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ batch_normalization       │ (None, 224, 224, 72)   │            288 │ activation[0][0]       │
# │ (BatchNormalization)      │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ conv2d_1 (Conv2D)         │ (None, 112, 112, 72)   │         46,656 │ batch_normalization[0… │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ batch_normalization_1     │ (None, 112, 112, 72)   │            288 │ conv2d_1[0][0]         │
# │ (BatchNormalization)      │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ re_lu (ReLU)              │ (None, 112, 112, 72)   │              0 │ batch_normalization_1… │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ conv2d_2 (Conv2D)         │ (None, 112, 112, 72)   │         46,656 │ re_lu[0][0]            │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ batch_normalization_2     │ (None, 112, 112, 72)   │            288 │ conv2d_2[0][0]         │
# │ (BatchNormalization)      │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ global_average_pooling2d  │ (None, 72)             │              0 │ batch_normalization_2… │
# │ (GlobalAveragePooling2D)  │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ reshape (Reshape)         │ (None, 1, 1, 72)       │              0 │ global_average_poolin… │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ dense (Dense)             │ (None, 1, 1, 18)       │          1,314 │ reshape[0][0]          │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ dense_1 (Dense)           │ (None, 1, 1, 72)       │          1,368 │ dense[0][0]            │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ multiply (Multiply)       │ (None, 112, 112, 72)   │              0 │ batch_normalization_2… │
# │                           │                        │                │ dense_1[0][0]          │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ dropout (Dropout)         │ (None, 112, 112, 72)   │              0 │ multiply[0][0]         │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ stochastic_depth          │ (None, 112, 112, 72)   │              0 │ dropout[0][0]          │
# │ (StochasticDepth)         │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ conv2d_3 (Conv2D)         │ (None, 112, 112, 144)  │         93,312 │ stochastic_depth[0][0] │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ batch_normalization_3     │ (None, 112, 112, 144)  │            576 │ conv2d_3[0][0]         │
# │ (BatchNormalization)      │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ re_lu_1 (ReLU)            │ (None, 112, 112, 144)  │              0 │ batch_normalization_3… │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ conv2d_4 (Conv2D)         │ (None, 112, 112, 144)  │        186,624 │ re_lu_1[0][0]          │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ batch_normalization_4     │ (None, 112, 112, 144)  │            576 │ conv2d_4[0][0]         │
# │ (BatchNormalization)      │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ global_average_pooling2d… │ (None, 144)            │              0 │ batch_normalization_4… │
# │ (GlobalAveragePooling2D)  │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ reshape_1 (Reshape)       │ (None, 1, 1, 144)      │              0 │ global_average_poolin… │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ dense_2 (Dense)           │ (None, 1, 1, 36)       │          5,220 │ reshape_1[0][0]        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ dense_3 (Dense)           │ (None, 1, 1, 144)      │          5,328 │ dense_2[0][0]          │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ multiply_1 (Multiply)     │ (None, 112, 112, 144)  │              0 │ batch_normalization_4… │
# │                           │                        │                │ dense_3[0][0]          │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ dropout_1 (Dropout)       │ (None, 112, 112, 144)  │              0 │ multiply_1[0][0]       │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ stochastic_depth_1        │ (None, 112, 112, 144)  │              0 │ dropout_1[0][0]        │
# │ (StochasticDepth)         │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ conv2d_5 (Conv2D)         │ (None, 112, 112, 288)  │        373,248 │ stochastic_depth_1[0]… │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ batch_normalization_5     │ (None, 112, 112, 288)  │          1,152 │ conv2d_5[0][0]         │
# │ (BatchNormalization)      │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ re_lu_2 (ReLU)            │ (None, 112, 112, 288)  │              0 │ batch_normalization_5… │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ conv2d_6 (Conv2D)         │ (None, 112, 112, 288)  │        746,496 │ re_lu_2[0][0]          │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ batch_normalization_6     │ (None, 112, 112, 288)  │          1,152 │ conv2d_6[0][0]         │
# │ (BatchNormalization)      │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ global_average_pooling2d… │ (None, 288)            │              0 │ batch_normalization_6… │
# │ (GlobalAveragePooling2D)  │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ reshape_2 (Reshape)       │ (None, 1, 1, 288)      │              0 │ global_average_poolin… │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ dense_4 (Dense)           │ (None, 1, 1, 72)       │         20,808 │ reshape_2[0][0]        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ dense_5 (Dense)           │ (None, 1, 1, 288)      │         21,024 │ dense_4[0][0]          │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ multiply_2 (Multiply)     │ (None, 112, 112, 288)  │              0 │ batch_normalization_6… │
# │                           │                        │                │ dense_5[0][0]          │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ dropout_2 (Dropout)       │ (None, 112, 112, 288)  │              0 │ multiply_2[0][0]       │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ stochastic_depth_2        │ (None, 112, 112, 288)  │              0 │ dropout_2[0][0]        │
# │ (StochasticDepth)         │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ conv2d_7 (Conv2D)         │ (None, 112, 112, 576)  │      1,492,992 │ stochastic_depth_2[0]… │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ batch_normalization_7     │ (None, 112, 112, 576)  │          2,304 │ conv2d_7[0][0]         │
# │ (BatchNormalization)      │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ re_lu_3 (ReLU)            │ (None, 112, 112, 576)  │              0 │ batch_normalization_7… │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ conv2d_8 (Conv2D)         │ (None, 112, 112, 576)  │      2,985,984 │ re_lu_3[0][0]          │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ batch_normalization_8     │ (None, 112, 112, 576)  │          2,304 │ conv2d_8[0][0]         │
# │ (BatchNormalization)      │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ global_average_pooling2d… │ (None, 576)            │              0 │ batch_normalization_8… │
# │ (GlobalAveragePooling2D)  │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ reshape_3 (Reshape)       │ (None, 1, 1, 576)      │              0 │ global_average_poolin… │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ dense_6 (Dense)           │ (None, 1, 1, 144)      │         83,088 │ reshape_3[0][0]        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ dense_7 (Dense)           │ (None, 1, 1, 576)      │         83,520 │ dense_6[0][0]          │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ multiply_3 (Multiply)     │ (None, 112, 112, 576)  │              0 │ batch_normalization_8… │
# │                           │                        │                │ dense_7[0][0]          │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ dropout_3 (Dropout)       │ (None, 112, 112, 576)  │              0 │ multiply_3[0][0]       │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ stochastic_depth_3        │ (None, 112, 112, 576)  │              0 │ dropout_3[0][0]        │
# │ (StochasticDepth)         │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ global_average_pooling2d… │ (None, 576)            │              0 │ stochastic_depth_3[0]… │
# │ (GlobalAveragePooling2D)  │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ dense_8 (Dense)           │ (None, 6)              │          3,462 │ global_average_poolin… │
# └───────────────────────────┴────────────────────────┴────────────────┴────────────────────────┘
#  Total params: 6,207,972 (23.68 MB)
#  Trainable params: 6,203,508 (23.66 MB)
#  Non-trainable params: 4,464 (17.44 KB)
# 54

# %%
from tensorflow.keras.optimizers import Nadam

total_epochs = 110
initial_lr = 3e-5
max_lr = 1e-3
min_lr = 1e-7

optimizer = Nadam(learning_rate=initial_lr, clipnorm=1.0)

# Implement the 1cycle learning rate policy
def lr_schedule(epoch, lr):
    if epoch < total_epochs * 0.4:  # Ramp-up (0-40%)
        lr = initial_lr + (max_lr - initial_lr) * (epoch / (total_epochs * 0.4))
    elif epoch < total_epochs * 0.8:  # Ramp-down (40-80%)
        lr = max_lr - (max_lr - initial_lr) * ((epoch - total_epochs * 0.4) / (total_epochs * 0.4))
    else:  # Final decay (80-100%)
        lr = initial_lr - (initial_lr - min_lr) * ((epoch - total_epochs * 0.8) / (total_epochs * 0.2))
    return lr
# Callbacks
lr_scheduler = tf.keras.callbacks.LearningRateScheduler(lr_schedule)

# %%
# Automatically logs training metrics and hyperparameters
#!pip install wandb
import wandb
from wandb.integration.keras import WandbCallback
from tensorflow.keras.optimizers import Nadam

wandb.init(project="Airplane-track")
wandb_callback = WandbCallback(save_graph=False, save_model=False)
print(wandb.run.name)
#optimizer = Nadam(learning_rate=3e-4, clipnorm=1.0)
#Compile the model
small_model.compile(
    optimizer=optimizer,
    loss="sparse_categorical_crossentropy",
    metrics=["accuracy"],
)
checkpoint = tf.keras.callbacks.ModelCheckpoint(
    wandb.run.name + ".keras",
    monitor='val_loss',  # monitor validation loss or any desired metric
    verbose=1,
    save_best_only=True,
    mode='min'  # 'min' for metrics like loss, 'max' for accuracy
)
# Out:
# wandb: Using wandb-core as the SDK backend.  Please refer to https://wandb.me/wandb-core for more information.
# wandb: WARNING If you're specifying your api key in code, ensure this code is not shared publicly.
# wandb: WARNING Consider setting the WANDB_API_KEY environment variable, or running `wandb login` from the command line.
# wandb: No netrc file found, creating one.
# wandb: Appending key for api.wandb.ai to your netrc file: /root/.netrc
# wandb: Currently logged in as: 599002 (599002-h-gskulen-p-vestlandet) to https://api.wandb.ai. Use `wandb login --relogin` to force relogin
# Tracking run with wandb version 0.19.8
# Run data is saved locally in <code>/content/wandb/run-20250318_114040-m6r5vvqr</code>
# Syncing run <strong><a href='https://wandb.ai/599002-h-gskulen-p-vestlandet/Airplane-track/runs/m6r5vvqr' target="_blank">likely-wind-52</a></strong> to <a href='https://wandb.ai/599002-h-gskulen-p-vestlandet/Airplane-track' target="_blank">Weights & Biases</a> (<a href='https://wandb.me/developer-guide' target="_blank">docs</a>)<br>
#  View project at <a href='https://wandb.ai/599002-h-gskulen-p-vestlandet/Airplane-track' target="_blank">https://wandb.ai/599002-h-gskulen-p-vestlandet/Airplane-track</a>
#  View run at <a href='https://wandb.ai/599002-h-gskulen-p-vestlandet/Airplane-track/runs/m6r5vvqr' target="_blank">https://wandb.ai/599002-h-gskulen-p-vestlandet/Airplane-track/runs/m6r5vvqr</a>
# wandb: WARNING WandbCallback is deprecated and will be removed in a future release. Please use the WandbMetricsLogger, WandbModelCheckpoint, and WandbEvalCallback callbacks instead. See https://docs.wandb.ai/guides/integrations/keras for more information.
# likely-wind-52

# %%
history = small_model.fit(
    train_airplane,
    epochs=110,
    validation_data=val_airplane,
    callbacks=[
        #early_stopping,
        lr_scheduler,
        checkpoint,
        wandb_callback],
)

import matplotlib.pyplot as plt

# Retrieve training history
accuracy = history.history["accuracy"]
val_accuracy = history.history["val_accuracy"]
loss = history.history["loss"]
val_loss = history.history["val_loss"]
epochs = range(1, len(accuracy) + 1)
learning_rate = history.history["learning_rate"]

# Plot accuracy
plt.figure(figsize=(12, 5))
plt.subplot(1, 2, 1)
plt.plot(epochs, accuracy, "bo-", label="Training Accuracy")
plt.plot(epochs, val_accuracy, "ro-", label="Validation Accuracy")
plt.title("Training & Validation Accuracy")
plt.xlabel("Epochs")
plt.ylabel("Accuracy")
plt.legend()
plt.grid()

# Plot loss
plt.subplot(1, 2, 2)
plt.plot(epochs, loss, "bo-", label="Training Loss")
plt.plot(epochs, val_loss, "ro-", label="Validation Loss")
plt.title("Training & Validation Loss")
plt.xlabel("Epochs")
plt.ylabel("Loss")
plt.legend()
plt.grid()

plt.show()

# Plot loss
plt.figure(figsize=(12, 5))
plt.plot(epochs, learning_rate, "bo-", label="Learning rate")
plt.title("Learning rate")
plt.xlabel("Epochs")
plt.ylabel("Lr")
plt.legend()
plt.grid()

plt.show()

wandb.log({
    "Final Training Accuracy": history.history["accuracy"][-1],
    "Final Validation Accuracy": history.history["val_accuracy"][-1],
    "Final Training Loss": history.history["loss"][-1],
    "Final Validation Loss": history.history["val_loss"][-1],
})

test_loss, test_accuracy = small_model.evaluate(test_airplane)
print(f"Test Accuracy: {test_accuracy:.4f}")
print(f"Test Loss: {test_loss:.4f}")
wandb.log({
    "Test Accuracy": test_accuracy,
    "Test Loss": test_loss,
})
wandb.save(wandb.run.name + ".keras")
wandb.finish()
# Out:
# Epoch 1/110
# 104/104 ━━━━━━━━━━━━━━━━━━━━ 0s 221ms/step - accuracy: 0.0078 - loss: nan
# Epoch 1: val_loss did not improve from inf
# 104/104 ━━━━━━━━━━━━━━━━━━━━ 149s 359ms/step - accuracy: 0.0079 - loss: nan - val_accuracy: 0.0102 - val_loss: nan - learning_rate: 3.0000e-05
# Epoch 2/110
# 104/104 ━━━━━━━━━━━━━━━━━━━━ 0s 222ms/step - accuracy: 0.0121 - loss: nan
# Epoch 2: val_loss did not improve from inf
# 104/104 ━━━━━━━━━━━━━━━━━━━━ 36s 284ms/step - accuracy: 0.0120 - loss: nan - val_accuracy: 0.0102 - val_loss: nan - learning_rate: 5.2045e-05
# Epoch 3/110
# 104/104 ━━━━━━━━━━━━━━━━━━━━ 0s 221ms/step - accuracy: 0.0109 - loss: nan
# Epoch 3: val_loss did not improve from inf
# 104/104 ━━━━━━━━━━━━━━━━━━━━ 36s 284ms/step - accuracy: 0.0108 - loss: nan - val_accuracy: 0.0102 - val_loss: nan - learning_rate: 7.4091e-05
# Epoch 4/110
# 104/104 ━━━━━━━━━━━━━━━━━━━━ 0s 221ms/step - accuracy: 0.0096 - loss: nan
# Epoch 4: val_loss did not improve from inf
# 104/104 ━━━━━━━━━━━━━━━━━━━━ 36s 284ms/step - accuracy: 0.0096 - loss: nan - val_accuracy: 0.0102 - val_loss: nan - learning_rate: 9.6136e-05
# Epoch 5/110
#  55/104 ━━━━━━━━━━━━━━━━━━━━ 10s 221ms/step - accuracy: 0.0118 - loss: nan
